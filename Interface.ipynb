# %%
import filereader
import numpy as np
import gurobipy as gp
import scipy

# %%
groceries_dict = filereader.read_grocery_info()

# %%
recipes_dict = filereader.read_recipes()

# %%
nutrition_needs_dict = filereader.read_nutrition()

# %%
# generate the matrices that we care about
# we first need to be certain of order of stuff, so let's generate these lists of keys
groceries_list = [key for key in groceries_dict.keys()]
recipes_list = [key for key in recipes_dict.keys()]
nutrients_list = [key for key in nutrition_needs_dict.keys()]

# # generate the N matrix (but this will actually be a dictionary)
# N = {}
# for recipe, ingredients in recipes_dict.items():
#     N[recipe]

N = [
    [
        sum([groceries_dict[ingredient]["nutrients"][nutrient]/groceries_dict[ingredient]["Serving Size (g)"]*recipes_dict[recipe][ingredient] for ingredient in recipes_dict[recipe]])
    for nutrient in nutrients_list]
    for recipe in recipes_list
]

# c = np.array([groceries_dict[ingredient]["Price (CAD)"] for ingredient in groceries_list])

# %%
np.max(N)
# Out:
# 6770.6

# %%
# need to transpose the recipes dict
recipes_dict_transpose = {}

for ik in groceries_dict.keys():
    recipes_dict_transpose[ik] = {}

for rk, rv in recipes_dict.items():
    for ik, iv in rv.items():
        recipes_dict_transpose[ik][rk] = iv

# first entry is a list, with an entry for each ingredient, containing a list of the indices of all the recipes
# the second entry is a list of lists of corresponding masses
recipes_transpose_csr_ish = [[],[]]
for ik, iv in recipes_dict_transpose.items():
    recipes_transpose_csr_ish[0].append([recipes_list.index(recipe) for recipe in iv.keys()])
    recipes_transpose_csr_ish[1].append([mass for mass in iv.values()])

# %%
N_dict = {}
for rk, rv in recipes_dict.items():
    nutrients_dict = {}
    for nutrient in nutrition_needs_dict.keys():
        nutrients_dict[nutrient] = 0
    for gk, gv in rv.items():
        for nk, nv in groceries_dict[gk]["nutrients"].items():
            nutrients_dict[nk] += nv*gv/groceries_dict[gk]["Serving Size (g)"]
    N_dict[rk] = nutrients_dict

# %%
# here, we define the cost, which is time-dependent
# for this reason, we need to be clear about the number of days we are considering

# the number of days we consider (one month)
# t_max = 30
t_max = 7

# the standard deviation for the random variation in price
price_sigma = 0.2

# costs for each item. Each is a list of 30 entries, one for each day
c_dict = {}
for gk, gv in groceries_dict.items():
    c_dict[gk] = gv["Price (CAD)"]*np.random.normal(loc=1, scale=price_sigma, size=t_max)

c_list = [gv["Price (CAD)"]*np.random.normal(loc=1, scale=price_sigma, size=t_max) for gk, gv in groceries_dict.items()]

# masses
m_dict = {}
for gk, gv in groceries_dict.items():
    m_dict[gk] = gv["Mass (g)"]

m_list = [gv["Mass (g)"] for gk, gv in groceries_dict.items()]

a_k = [nv for nk, nv in nutrition_needs_dict.items()]

# %%
model = gp.Model("New problem")

## seems that summation doesn't work unless we use the Gurobi addVars
# g_vars = {}
# u_vars = {}
# for gk in groceries_dict.keys():
#     u_vars[gk] = []
#     g_vars[gk] = model.addVars(t_max, vtype=gp.GRB.INTEGER, name=gk)
#     for t in range(t_max):
#         u_vars[gk].append(model.addVars(t+1, name=f"grams of {gk} used on day {t}"))


# r_vars = {}
# for rk in recipes_dict.keys():
#     r_vars[rk] = model.addVars(t_max, name=rk)

g_vars = model.addVars(len(groceries_list), t_max, vtype=gp.GRB.INTEGER, name="g[i][t]")
u_vars = model.addVars(len(groceries_list), t_max, t_max, name="u[i][tau][t]")
# r_vars = model.addVars(len(recipes_list), t_max, name="r[j][t]")
r_vars = model.addMVar((len(recipes_list), t_max), name="r[j][t]")

s = model.addVars(t_max, vtype=gp.GRB.BINARY, name="s")

model.setParam("LogToConsole", 1)  # Enable console logging
model.setParam("OutputFlag", 1)    # Enable all output

model.update()
# Out:
# Set parameter LogToConsole to value 1
# Set parameter OutputFlag to value 1

# %%
(np.array(a_k)*np.expand_dims(np.arange(t_max), axis=1)).shape
# Out:
# (7, 16)

# %%
np.array(a_k)
# Out:
# array([3.0e+03, 5.6e+01, 2.3e+03, 4.7e+03, 1.3e+03, 4.1e+02, 1.1e+01,
#        1.1e+01, 9.0e+02, 1.2e+00, 1.3e+00, 1.6e+01, 1.3e+00, 2.4e+00,
#        7.5e+01, 1.5e+01])

# %%
np.max(np.array(N).transpose())
# Out:
# 6770.6

# %%
np.max(m_list)
# Out:
# 2000.0

# %%
for t in range(t_max):
    model.addMConstr(np.array(N).transpose(), r_vars[:,t], '>=', np.array(a_k))

model.addConstrs((g_vars[gk, t] <= 999999*s[t] for gk in range(len(groceries_list))
                  for t in range(t_max)), 
                  name="Buy only on shopping days")

for t in range(t_max):
    model.addConstrs(
        (
            # u_vars[i,tau,t] <= g_vars[i,tau]*m_list[i] - u_vars.sum(i,tau,'*') for i in range(len(groceries_list)) for tau in range(t)
            u_vars[i,tau,t] <= g_vars[i,tau]*m_list[i] - sum(u_vars[i,tau,gamma] for gamma in range(max(0,tau-1))) for i in range(len(groceries_list)) for tau in range(t+1)
        )
    )
    
# enforce that u matches what we're using
# for ik, R_i in enumerate(recipes_transpose_csr_ish):
for i, iv in enumerate(recipes_transpose_csr_ish[0]):
    masses_required = recipes_transpose_csr_ish[1][i]
    print(f"ingredient {i}/{len(recipes_transpose_csr_ish[0])}")
    for t in range(t_max):
        # model.addConstrs((
        model.addConstr((
            sum(r_vars[iv[ind], t]*masses_required[ind]  for ind in range(len(iv))) == sum(u_vars[i, tau, t] for tau in range(
                # (0 if t < int(groceries_dict[groceries_list[j]]["Shelf Life (Days)"]) 
                #     else t - int(groceries_dict[groceries_list[j]]["Shelf Life (Days)"])), 
                    t+1
                ))
        ))


model.update()
# Out:
# ingredient 0/49
# ingredient 1/49
# ingredient 2/49
# ingredient 3/49
# ingredient 4/49
# ingredient 5/49
# ingredient 6/49
# ingredient 7/49
# ingredient 8/49
# ingredient 9/49
# ingredient 10/49
# ingredient 11/49
# ingredient 12/49
# ingredient 13/49
# ingredient 14/49
# ingredient 15/49
# ingredient 16/49
# ingredient 17/49
# ingredient 18/49
# ingredient 19/49
# ingredient 20/49
# ingredient 21/49
# ingredient 22/49
# ingredient 23/49
# ingredient 24/49
# ingredient 25/49
# ingredient 26/49
# ingredient 27/49
# ingredient 28/49
# ingredient 29/49
# ingredient 30/49
# ingredient 31/49
# ingredient 32/49
# ingredient 33/49
# ingredient 34/49
# ingredient 35/49
# ingredient 36/49
# ingredient 37/49
# ingredient 38/49
# ingredient 39/49
# ingredient 40/49
# ingredient 41/49
# ingredient 42/49
# ingredient 43/49
# ingredient 44/49
# ingredient 45/49
# ingredient 46/49
# ingredient 47/49
# ingredient 48/49

# %%
recipes_dict_transpose
# Out:
# {'Beef': {'Zurich-Style Meat Saute': 600.0,
#   'Hakka-Style Meatballs': 227.0,
#   'Beef and Broccoli': 227.0},
#  'Mushrooms': {'Zurich-Style Meat Saute': 250.0,
#   'One-Pot Chicken Tetrazzini': 227.0},
#  'Onion': {'Zurich-Style Meat Saute': 150.0,
#   'Galinha Caipira': 150.0,
#   'Grilled Mackerel with Miso Soup and Squash': 50.0,
#   'Tajine Maadnous': 150.0,
#   'Exotic Ginger Cumin Chicken': 75.0,
#   'Hakka-Style Meatballs': 70.0,
#   'One-Pot Chicken Tetrazzini': 70.0,
#   'Smoked Salmon Pasta Primavera': 70.0,
#   'Three Bean Salad': 70.0,
#   'Fajitas': 150.0,
#   'Smoked Salmon Quiche': 75.0},
#  'Flour': {'Zurich-Style Meat Saute': 8.0,
#   'Spiced Apple Pancakes': 250.0,
#   'Grostoli': 800.0,
#   'One-Pot Chicken Tetrazzini': 24.0,
#   'Smoked Salmon Pasta Primavera': 24.0,
#   'Spicy Kung Pao-Style Chicken': 30.0,
#   'Smoked Salmon Quiche': 220.0},
#  'Cream': {'Zurich-Style Meat Saute': 200.0, 'Smoked Salmon Quiche': 240.0},
#  'Parsley': {'Zurich-Style Meat Saute': 5.0,
#   'Tajine Maadnous': 50.0,
#   'One-Pot Chicken Tetrazzini': 30.0},
#  'Chicken': {'Galinha Caipira': 2500.0,
#   'Tajine Maadnous': 454.0,
#   'Exotic Ginger Cumin Chicken': 907.0,
#   'One-Pot Chicken Tetrazzini': 450.0,
#   'Spicy Kung Pao-Style Chicken': 680.0,
#   "Za'atar Chicken Bulghur Bowls": 680.0,
#   'Fajitas': 454.0},
#  'Chives': {'Galinha Caipira': 50.0,
#   'Spicy Kung Pao-Style Chicken': 30.0,
#   'Smoked Salmon Quiche': 2.0},
#  'Butter': {'Galinha Caipira': 15.0,
#   'Grilled Mackerel with Miso Soup and Squash': 14.0,
#   'Risengrød': 50.0,
#   'Grostoli': 42.0,
#   'One-Pot Chicken Tetrazzini': 42.0,
#   'Smoked Salmon Pasta Primavera': 14.0,
#   'Smoked Salmon Quiche': 250.0},
#  'Mackerel': {'Grilled Mackerel with Miso Soup and Squash': 200.0},
#  'Miso Paste': {'Grilled Mackerel with Miso Soup and Squash': 30.0},
#  'Squash': {'Grilled Mackerel with Miso Soup and Squash': 150.0},
#  'Rice': {'Grilled Mackerel with Miso Soup and Squash': 185.0,
#   'Risengrød': 180.0,
#   'Hakka-Style Meatballs': 150.0,
#   'Spicy Kung Pao-Style Chicken': 138.0},
#  'Soy Sauce': {'Grilled Mackerel with Miso Soup and Squash': 15.0,
#   'Hakka-Style Meatballs': 30.0,
#   'Spicy Kung Pao-Style Chicken': 30.0,
#   'Beef and Broccoli': 15.0,
#   'Fajitas': 15.0},
#  'Milk': {'Risengrød': 1000.0,
#   'Spiced Apple Pancakes': 160.0,
#   'Grostoli': 240.0,
#   'One-Pot Chicken Tetrazzini': 960.0,
#   'Smoked Salmon Pasta Primavera': 600.0,
#   'Smoked Salmon Quiche': 240.0},
#  'Salt': {'Risengrød': 1.0,
#   'Tajine Maadnous': 6.0,
#   'Grostoli': 1.0,
#   'Three Bean Salad': 6.0,
#   'Fajitas': 6.0},
#  'Sugar': {'Risengrød': 50.0,
#   'Spiced Apple Pancakes': 12.5,
#   'Grostoli': 200.0,
#   'Exotic Ginger Cumin Chicken': 4.0,
#   'Three Bean Salad': 50.0,
#   "Za'atar Chicken Bulghur Bowls": 4.0},
#  'Cinnamon': {'Risengrød': 4.0,
#   'Spiced Apple Pancakes': 8.0,
#   'Tajine Maadnous': 0.5},
#  'Apple': {'Spiced Apple Pancakes': 200.0},
#  'Egg': {'Spiced Apple Pancakes': 50.0,
#   'Tajine Maadnous': 60.0,
#   'Grostoli': 200.0,
#   'Smoked Salmon Quiche': 250.0},
#  'Cheese': {'Tajine Maadnous': 170.0, "Za'atar Chicken Bulghur Bowls": 75.0},
#  'Olive Oil': {'Tajine Maadnous': 30.0,
#   'Hakka-Style Meatballs': 15.0,
#   'Spicy Kung Pao-Style Chicken': 15.0,
#   'Three Bean Salad': 79.0,
#   "Za'atar Chicken Bulghur Bowls": 15.0,
#   'Beef and Broccoli': 30.0,
#   'Fajitas': 41.25},
#  'Baking Powder': {'Grostoli': 12.0},
#  'Tomatoes': {'Exotic Ginger Cumin Chicken': 544.0,
#   "Za'atar Chicken Bulghur Bowls": 300.0},
#  'Stock': {'Exotic Ginger Cumin Chicken': 120.0, 'Beef and Broccoli': 120.0},
#  'Tomato Paste': {'Exotic Ginger Cumin Chicken': 30.0},
#  'Yogurt': {'Exotic Ginger Cumin Chicken': 180.0},
#  'Panko': {'Hakka-Style Meatballs': 30.0},
#  'Ginger': {'Exotic Ginger Cumin Chicken': 15.0,
#   'Hakka-Style Meatballs': 14.0,
#   'Spicy Kung Pao-Style Chicken': 6.0,
#   'Beef and Broccoli': 6.0},
#  'Bell Pepper': {'Hakka-Style Meatballs': 240.0,
#   'One-Pot Chicken Tetrazzini': 150.0,
#   'Spicy Kung Pao-Style Chicken': 100.0,
#   'Three Bean Salad': 150.0,
#   'Fajitas': 120.0},
#  'Cilantro': {'Hakka-Style Meatballs': 15.0, 'Three Bean Salad': 15.0},
#  'Green Peas': {'Hakka-Style Meatballs': 57.0,
#   'One-Pot Chicken Tetrazzini': 75.0,
#   'Smoked Salmon Pasta Primavera': 150.0,
#   'Beef and Broccoli': 100.0},
#  'Garlic': {'One-Pot Chicken Tetrazzini': 3.0,
#   'Smoked Salmon Pasta Primavera': 6.0,
#   'Spicy Kung Pao-Style Chicken': 6.0,
#   "Za'atar Chicken Bulghur Bowls": 6.0,
#   'Beef and Broccoli': 6.0,
#   'Fajitas': 12.0,
#   'Smoked Salmon Quiche': 3.0},
#  'Noodles': {'One-Pot Chicken Tetrazzini': 227.0,
#   'Smoked Salmon Pasta Primavera': 340.0},
#  'Worcestershire Sauce': {'One-Pot Chicken Tetrazzini': 30.0},
#  'Asparagus': {'Smoked Salmon Pasta Primavera': 227.0},
#  'Green Beans': {'Smoked Salmon Pasta Primavera': 113.0,
#   'Three Bean Salad': 480.0},
#  'Smoked Salmon': {'Smoked Salmon Pasta Primavera': 113.0,
#   'Smoked Salmon Quiche': 397.0},
#  'Fresh Mint': {'Smoked Salmon Pasta Primavera': 15.0},
#  'Lemon': {'Smoked Salmon Pasta Primavera': 50.0,
#   "Za'atar Chicken Bulghur Bowls": 100.0},
#  'Celery': {'Spicy Kung Pao-Style Chicken': 150.0},
#  'Cider Vinegar': {'Three Bean Salad': 120.0,
#   "Za'atar Chicken Bulghur Bowls": 30.0},
#  'Carrot': {'Three Bean Salad': 60.0, 'Beef and Broccoli': 130.0},
#  'Bulghur Wheat': {"Za'atar Chicken Bulghur Bowls": 150.0},
#  'Olives': {"Za'atar Chicken Bulghur Bowls": 28.0},
#  'Spinach': {"Za'atar Chicken Bulghur Bowls": 113.0},
#  'Broccoli': {'Beef and Broccoli': 90.0},
#  'Lime Juice': {'Fajitas': 62.5},
#  'Banana': {'Bananas': 190.0}}

# %%
g_vars
# Out:
# {(0, 0): <gurobi.Var g[i][t][0,0]>,
#  (0, 1): <gurobi.Var g[i][t][0,1]>,
#  (0, 2): <gurobi.Var g[i][t][0,2]>,
#  (0, 3): <gurobi.Var g[i][t][0,3]>,
#  (0, 4): <gurobi.Var g[i][t][0,4]>,
#  (0, 5): <gurobi.Var g[i][t][0,5]>,
#  (0, 6): <gurobi.Var g[i][t][0,6]>,
#  (1, 0): <gurobi.Var g[i][t][1,0]>,
#  (1, 1): <gurobi.Var g[i][t][1,1]>,
#  (1, 2): <gurobi.Var g[i][t][1,2]>,
#  (1, 3): <gurobi.Var g[i][t][1,3]>,
#  (1, 4): <gurobi.Var g[i][t][1,4]>,
#  (1, 5): <gurobi.Var g[i][t][1,5]>,
#  (1, 6): <gurobi.Var g[i][t][1,6]>,
#  (2, 0): <gurobi.Var g[i][t][2,0]>,
#  (2, 1): <gurobi.Var g[i][t][2,1]>,
#  (2, 2): <gurobi.Var g[i][t][2,2]>,
#  (2, 3): <gurobi.Var g[i][t][2,3]>,
#  (2, 4): <gurobi.Var g[i][t][2,4]>,
#  (2, 5): <gurobi.Var g[i][t][2,5]>,
#  (2, 6): <gurobi.Var g[i][t][2,6]>,
#  (3, 0): <gurobi.Var g[i][t][3,0]>,
#  (3, 1): <gurobi.Var g[i][t][3,1]>,
#  (3, 2): <gurobi.Var g[i][t][3,2]>,
#  (3, 3): <gurobi.Var g[i][t][3,3]>,
#  (3, 4): <gurobi.Var g[i][t][3,4]>,
#  (3, 5): <gurobi.Var g[i][t][3,5]>,
#  (3, 6): <gurobi.Var g[i][t][3,6]>,
#  (4, 0): <gurobi.Var g[i][t][4,0]>,
#  (4, 1): <gurobi.Var g[i][t][4,1]>,
#  (4, 2): <gurobi.Var g[i][t][4,2]>,
#  (4, 3): <gurobi.Var g[i][t][4,3]>,
#  (4, 4): <gurobi.Var g[i][t][4,4]>,
#  (4, 5): <gurobi.Var g[i][t][4,5]>,
#  (4, 6): <gurobi.Var g[i][t][4,6]>,
#  (5, 0): <gurobi.Var g[i][t][5,0]>,
#  (5, 1): <gurobi.Var g[i][t][5,1]>,
#  (5, 2): <gurobi.Var g[i][t][5,2]>,
#  (5, 3): <gurobi.Var g[i][t][5,3]>,
#  (5, 4): <gurobi.Var g[i][t][5,4]>,
#  (5, 5): <gurobi.Var g[i][t][5,5]>,
#  (5, 6): <gurobi.Var g[i][t][5,6]>,
#  (6, 0): <gurobi.Var g[i][t][6,0]>,
#  (6, 1): <gurobi.Var g[i][t][6,1]>,
#  (6, 2): <gurobi.Var g[i][t][6,2]>,
#  (6, 3): <gurobi.Var g[i][t][6,3]>,
#  (6, 4): <gurobi.Var g[i][t][6,4]>,
#  (6, 5): <gurobi.Var g[i][t][6,5]>,
#  (6, 6): <gurobi.Var g[i][t][6,6]>,
#  (7, 0): <gurobi.Var g[i][t][7,0]>,
#  (7, 1): <gurobi.Var g[i][t][7,1]>,
#  (7, 2): <gurobi.Var g[i][t][7,2]>,
#  (7, 3): <gurobi.Var g[i][t][7,3]>,
#  (7, 4): <gurobi.Var g[i][t][7,4]>,
#  (7, 5): <gurobi.Var g[i][t][7,5]>,
#  (7, 6): <gurobi.Var g[i][t][7,6]>,
#  (8, 0): <gurobi.Var g[i][t][8,0]>,
#  (8, 1): <gurobi.Var g[i][t][8,1]>,
#  (8, 2): <gurobi.Var g[i][t][8,2]>,
#  (8, 3): <gurobi.Var g[i][t][8,3]>,
#  (8, 4): <gurobi.Var g[i][t][8,4]>,
#  (8, 5): <gurobi.Var g[i][t][8,5]>,
#  (8, 6): <gurobi.Var g[i][t][8,6]>,
#  (9, 0): <gurobi.Var g[i][t][9,0]>,
#  (9, 1): <gurobi.Var g[i][t][9,1]>,
#  (9, 2): <gurobi.Var g[i][t][9,2]>,
#  (9, 3): <gurobi.Var g[i][t][9,3]>,
#  (9, 4): <gurobi.Var g[i][t][9,4]>,
#  (9, 5): <gurobi.Var g[i][t][9,5]>,
#  (9, 6): <gurobi.Var g[i][t][9,6]>,
#  (10, 0): <gurobi.Var g[i][t][10,0]>,
#  (10, 1): <gurobi.Var g[i][t][10,1]>,
#  (10, 2): <gurobi.Var g[i][t][10,2]>,
#  (10, 3): <gurobi.Var g[i][t][10,3]>,
#  (10, 4): <gurobi.Var g[i][t][10,4]>,
#  (10, 5): <gurobi.Var g[i][t][10,5]>,
#  (10, 6): <gurobi.Var g[i][t][10,6]>,
#  (11, 0): <gurobi.Var g[i][t][11,0]>,
#  (11, 1): <gurobi.Var g[i][t][11,1]>,
#  (11, 2): <gurobi.Var g[i][t][11,2]>,
#  (11, 3): <gurobi.Var g[i][t][11,3]>,
#  (11, 4): <gurobi.Var g[i][t][11,4]>,
#  (11, 5): <gurobi.Var g[i][t][11,5]>,
#  (11, 6): <gurobi.Var g[i][t][11,6]>,
#  (12, 0): <gurobi.Var g[i][t][12,0]>,
#  (12, 1): <gurobi.Var g[i][t][12,1]>,
#  (12, 2): <gurobi.Var g[i][t][12,2]>,
#  (12, 3): <gurobi.Var g[i][t][12,3]>,
#  (12, 4): <gurobi.Var g[i][t][12,4]>,
#  (12, 5): <gurobi.Var g[i][t][12,5]>,
#  (12, 6): <gurobi.Var g[i][t][12,6]>,
#  (13, 0): <gurobi.Var g[i][t][13,0]>,
#  (13, 1): <gurobi.Var g[i][t][13,1]>,
#  (13, 2): <gurobi.Var g[i][t][13,2]>,
#  (13, 3): <gurobi.Var g[i][t][13,3]>,
#  (13, 4): <gurobi.Var g[i][t][13,4]>,
#  (13, 5): <gurobi.Var g[i][t][13,5]>,
#  (13, 6): <gurobi.Var g[i][t][13,6]>,
#  (14, 0): <gurobi.Var g[i][t][14,0]>,
#  (14, 1): <gurobi.Var g[i][t][14,1]>,
#  (14, 2): <gurobi.Var g[i][t][14,2]>,
#  (14, 3): <gurobi.Var g[i][t][14,3]>,
#  (14, 4): <gurobi.Var g[i][t][14,4]>,
#  (14, 5): <gurobi.Var g[i][t][14,5]>,
#  (14, 6): <gurobi.Var g[i][t][14,6]>,
#  (15, 0): <gurobi.Var g[i][t][15,0]>,
#  (15, 1): <gurobi.Var g[i][t][15,1]>,
#  (15, 2): <gurobi.Var g[i][t][15,2]>,
#  (15, 3): <gurobi.Var g[i][t][15,3]>,
#  (15, 4): <gurobi.Var g[i][t][15,4]>,
#  (15, 5): <gurobi.Var g[i][t][15,5]>,
#  (15, 6): <gurobi.Var g[i][t][15,6]>,
#  (16, 0): <gurobi.Var g[i][t][16,0]>,
#  (16, 1): <gurobi.Var g[i][t][16,1]>,
#  (16, 2): <gurobi.Var g[i][t][16,2]>,
#  (16, 3): <gurobi.Var g[i][t][16,3]>,
#  (16, 4): <gurobi.Var g[i][t][16,4]>,
#  (16, 5): <gurobi.Var g[i][t][16,5]>,
#  (16, 6): <gurobi.Var g[i][t][16,6]>,
#  (17, 0): <gurobi.Var g[i][t][17,0]>,
#  (17, 1): <gurobi.Var g[i][t][17,1]>,
#  (17, 2): <gurobi.Var g[i][t][17,2]>,
#  (17, 3): <gurobi.Var g[i][t][17,3]>,
#  (17, 4): <gurobi.Var g[i][t][17,4]>,
#  (17, 5): <gurobi.Var g[i][t][17,5]>,
#  (17, 6): <gurobi.Var g[i][t][17,6]>,
#  (18, 0): <gurobi.Var g[i][t][18,0]>,
#  (18, 1): <gurobi.Var g[i][t][18,1]>,
#  (18, 2): <gurobi.Var g[i][t][18,2]>,
#  (18, 3): <gurobi.Var g[i][t][18,3]>,
#  (18, 4): <gurobi.Var g[i][t][18,4]>,
#  (18, 5): <gurobi.Var g[i][t][18,5]>,
#  (18, 6): <gurobi.Var g[i][t][18,6]>,
#  (19, 0): <gurobi.Var g[i][t][19,0]>,
#  (19, 1): <gurobi.Var g[i][t][19,1]>,
#  (19, 2): <gurobi.Var g[i][t][19,2]>,
#  (19, 3): <gurobi.Var g[i][t][19,3]>,
#  (19, 4): <gurobi.Var g[i][t][19,4]>,
#  (19, 5): <gurobi.Var g[i][t][19,5]>,
#  (19, 6): <gurobi.Var g[i][t][19,6]>,
#  (20, 0): <gurobi.Var g[i][t][20,0]>,
#  (20, 1): <gurobi.Var g[i][t][20,1]>,
#  (20, 2): <gurobi.Var g[i][t][20,2]>,
#  (20, 3): <gurobi.Var g[i][t][20,3]>,
#  (20, 4): <gurobi.Var g[i][t][20,4]>,
#  (20, 5): <gurobi.Var g[i][t][20,5]>,
#  (20, 6): <gurobi.Var g[i][t][20,6]>,
#  (21, 0): <gurobi.Var g[i][t][21,0]>,
#  (21, 1): <gurobi.Var g[i][t][21,1]>,
#  (21, 2): <gurobi.Var g[i][t][21,2]>,
#  (21, 3): <gurobi.Var g[i][t][21,3]>,
#  (21, 4): <gurobi.Var g[i][t][21,4]>,
#  (21, 5): <gurobi.Var g[i][t][21,5]>,
#  (21, 6): <gurobi.Var g[i][t][21,6]>,
#  (22, 0): <gurobi.Var g[i][t][22,0]>,
#  (22, 1): <gurobi.Var g[i][t][22,1]>,
#  (22, 2): <gurobi.Var g[i][t][22,2]>,
#  (22, 3): <gurobi.Var g[i][t][22,3]>,
#  (22, 4): <gurobi.Var g[i][t][22,4]>,
#  (22, 5): <gurobi.Var g[i][t][22,5]>,
#  (22, 6): <gurobi.Var g[i][t][22,6]>,
#  (23, 0): <gurobi.Var g[i][t][23,0]>,
#  (23, 1): <gurobi.Var g[i][t][23,1]>,
#  (23, 2): <gurobi.Var g[i][t][23,2]>,
#  (23, 3): <gurobi.Var g[i][t][23,3]>,
#  (23, 4): <gurobi.Var g[i][t][23,4]>,
#  (23, 5): <gurobi.Var g[i][t][23,5]>,
#  (23, 6): <gurobi.Var g[i][t][23,6]>,
#  (24, 0): <gurobi.Var g[i][t][24,0]>,
#  (24, 1): <gurobi.Var g[i][t][24,1]>,
#  (24, 2): <gurobi.Var g[i][t][24,2]>,
#  (24, 3): <gurobi.Var g[i][t][24,3]>,
#  (24, 4): <gurobi.Var g[i][t][24,4]>,
#  (24, 5): <gurobi.Var g[i][t][24,5]>,
#  (24, 6): <gurobi.Var g[i][t][24,6]>,
#  (25, 0): <gurobi.Var g[i][t][25,0]>,
#  (25, 1): <gurobi.Var g[i][t][25,1]>,
#  (25, 2): <gurobi.Var g[i][t][25,2]>,
#  (25, 3): <gurobi.Var g[i][t][25,3]>,
#  (25, 4): <gurobi.Var g[i][t][25,4]>,
#  (25, 5): <gurobi.Var g[i][t][25,5]>,
#  (25, 6): <gurobi.Var g[i][t][25,6]>,
#  (26, 0): <gurobi.Var g[i][t][26,0]>,
#  (26, 1): <gurobi.Var g[i][t][26,1]>,
#  (26, 2): <gurobi.Var g[i][t][26,2]>,
#  (26, 3): <gurobi.Var g[i][t][26,3]>,
#  (26, 4): <gurobi.Var g[i][t][26,4]>,
#  (26, 5): <gurobi.Var g[i][t][26,5]>,
#  (26, 6): <gurobi.Var g[i][t][26,6]>,
#  (27, 0): <gurobi.Var g[i][t][27,0]>,
#  (27, 1): <gurobi.Var g[i][t][27,1]>,
#  (27, 2): <gurobi.Var g[i][t][27,2]>,
#  (27, 3): <gurobi.Var g[i][t][27,3]>,
#  (27, 4): <gurobi.Var g[i][t][27,4]>,
#  (27, 5): <gurobi.Var g[i][t][27,5]>,
#  (27, 6): <gurobi.Var g[i][t][27,6]>,
#  (28, 0): <gurobi.Var g[i][t][28,0]>,
#  (28, 1): <gurobi.Var g[i][t][28,1]>,
#  (28, 2): <gurobi.Var g[i][t][28,2]>,
#  (28, 3): <gurobi.Var g[i][t][28,3]>,
#  (28, 4): <gurobi.Var g[i][t][28,4]>,
#  (28, 5): <gurobi.Var g[i][t][28,5]>,
#  (28, 6): <gurobi.Var g[i][t][28,6]>,
#  (29, 0): <gurobi.Var g[i][t][29,0]>,
#  (29, 1): <gurobi.Var g[i][t][29,1]>,
#  (29, 2): <gurobi.Var g[i][t][29,2]>,
#  (29, 3): <gurobi.Var g[i][t][29,3]>,
#  (29, 4): <gurobi.Var g[i][t][29,4]>,
#  (29, 5): <gurobi.Var g[i][t][29,5]>,
#  (29, 6): <gurobi.Var g[i][t][29,6]>,
#  (30, 0): <gurobi.Var g[i][t][30,0]>,
#  (30, 1): <gurobi.Var g[i][t][30,1]>,
#  (30, 2): <gurobi.Var g[i][t][30,2]>,
#  (30, 3): <gurobi.Var g[i][t][30,3]>,
#  (30, 4): <gurobi.Var g[i][t][30,4]>,
#  (30, 5): <gurobi.Var g[i][t][30,5]>,
#  (30, 6): <gurobi.Var g[i][t][30,6]>,
#  (31, 0): <gurobi.Var g[i][t][31,0]>,
#  (31, 1): <gurobi.Var g[i][t][31,1]>,
#  (31, 2): <gurobi.Var g[i][t][31,2]>,
#  (31, 3): <gurobi.Var g[i][t][31,3]>,
#  (31, 4): <gurobi.Var g[i][t][31,4]>,
#  (31, 5): <gurobi.Var g[i][t][31,5]>,
#  (31, 6): <gurobi.Var g[i][t][31,6]>,
#  (32, 0): <gurobi.Var g[i][t][32,0]>,
#  (32, 1): <gurobi.Var g[i][t][32,1]>,
#  (32, 2): <gurobi.Var g[i][t][32,2]>,
#  (32, 3): <gurobi.Var g[i][t][32,3]>,
#  (32, 4): <gurobi.Var g[i][t][32,4]>,
#  (32, 5): <gurobi.Var g[i][t][32,5]>,
#  (32, 6): <gurobi.Var g[i][t][32,6]>,
#  (33, 0): <gurobi.Var g[i][t][33,0]>,
#  (33, 1): <gurobi.Var g[i][t][33,1]>,
#  (33, 2): <gurobi.Var g[i][t][33,2]>,
#  (33, 3): <gurobi.Var g[i][t][33,3]>,
#  (33, 4): <gurobi.Var g[i][t][33,4]>,
#  (33, 5): <gurobi.Var g[i][t][33,5]>,
#  (33, 6): <gurobi.Var g[i][t][33,6]>,
#  (34, 0): <gurobi.Var g[i][t][34,0]>,
#  (34, 1): <gurobi.Var g[i][t][34,1]>,
#  (34, 2): <gurobi.Var g[i][t][34,2]>,
#  (34, 3): <gurobi.Var g[i][t][34,3]>,
#  (34, 4): <gurobi.Var g[i][t][34,4]>,
#  (34, 5): <gurobi.Var g[i][t][34,5]>,
#  (34, 6): <gurobi.Var g[i][t][34,6]>,
#  (35, 0): <gurobi.Var g[i][t][35,0]>,
#  (35, 1): <gurobi.Var g[i][t][35,1]>,
#  (35, 2): <gurobi.Var g[i][t][35,2]>,
#  (35, 3): <gurobi.Var g[i][t][35,3]>,
#  (35, 4): <gurobi.Var g[i][t][35,4]>,
#  (35, 5): <gurobi.Var g[i][t][35,5]>,
#  (35, 6): <gurobi.Var g[i][t][35,6]>,
#  (36, 0): <gurobi.Var g[i][t][36,0]>,
#  (36, 1): <gurobi.Var g[i][t][36,1]>,
#  (36, 2): <gurobi.Var g[i][t][36,2]>,
#  (36, 3): <gurobi.Var g[i][t][36,3]>,
#  (36, 4): <gurobi.Var g[i][t][36,4]>,
#  (36, 5): <gurobi.Var g[i][t][36,5]>,
#  (36, 6): <gurobi.Var g[i][t][36,6]>,
#  (37, 0): <gurobi.Var g[i][t][37,0]>,
#  (37, 1): <gurobi.Var g[i][t][37,1]>,
#  (37, 2): <gurobi.Var g[i][t][37,2]>,
#  (37, 3): <gurobi.Var g[i][t][37,3]>,
#  (37, 4): <gurobi.Var g[i][t][37,4]>,
#  (37, 5): <gurobi.Var g[i][t][37,5]>,
#  (37, 6): <gurobi.Var g[i][t][37,6]>,
#  (38, 0): <gurobi.Var g[i][t][38,0]>,
#  (38, 1): <gurobi.Var g[i][t][38,1]>,
#  (38, 2): <gurobi.Var g[i][t][38,2]>,
#  (38, 3): <gurobi.Var g[i][t][38,3]>,
#  (38, 4): <gurobi.Var g[i][t][38,4]>,
#  (38, 5): <gurobi.Var g[i][t][38,5]>,
#  (38, 6): <gurobi.Var g[i][t][38,6]>,
#  (39, 0): <gurobi.Var g[i][t][39,0]>,
#  (39, 1): <gurobi.Var g[i][t][39,1]>,
#  (39, 2): <gurobi.Var g[i][t][39,2]>,
#  (39, 3): <gurobi.Var g[i][t][39,3]>,
#  (39, 4): <gurobi.Var g[i][t][39,4]>,
#  (39, 5): <gurobi.Var g[i][t][39,5]>,
#  (39, 6): <gurobi.Var g[i][t][39,6]>,
#  (40, 0): <gurobi.Var g[i][t][40,0]>,
#  (40, 1): <gurobi.Var g[i][t][40,1]>,
#  (40, 2): <gurobi.Var g[i][t][40,2]>,
#  (40, 3): <gurobi.Var g[i][t][40,3]>,
#  (40, 4): <gurobi.Var g[i][t][40,4]>,
#  (40, 5): <gurobi.Var g[i][t][40,5]>,
#  (40, 6): <gurobi.Var g[i][t][40,6]>,
#  (41, 0): <gurobi.Var g[i][t][41,0]>,
#  (41, 1): <gurobi.Var g[i][t][41,1]>,
#  (41, 2): <gurobi.Var g[i][t][41,2]>,
#  (41, 3): <gurobi.Var g[i][t][41,3]>,
#  (41, 4): <gurobi.Var g[i][t][41,4]>,
#  (41, 5): <gurobi.Var g[i][t][41,5]>,
#  (41, 6): <gurobi.Var g[i][t][41,6]>,
#  (42, 0): <gurobi.Var g[i][t][42,0]>,
#  (42, 1): <gurobi.Var g[i][t][42,1]>,
#  (42, 2): <gurobi.Var g[i][t][42,2]>,
#  (42, 3): <gurobi.Var g[i][t][42,3]>,
#  (42, 4): <gurobi.Var g[i][t][42,4]>,
#  (42, 5): <gurobi.Var g[i][t][42,5]>,
#  (42, 6): <gurobi.Var g[i][t][42,6]>,
#  (43, 0): <gurobi.Var g[i][t][43,0]>,
#  (43, 1): <gurobi.Var g[i][t][43,1]>,
#  (43, 2): <gurobi.Var g[i][t][43,2]>,
#  (43, 3): <gurobi.Var g[i][t][43,3]>,
#  (43, 4): <gurobi.Var g[i][t][43,4]>,
#  (43, 5): <gurobi.Var g[i][t][43,5]>,
#  (43, 6): <gurobi.Var g[i][t][43,6]>,
#  (44, 0): <gurobi.Var g[i][t][44,0]>,
#  (44, 1): <gurobi.Var g[i][t][44,1]>,
#  (44, 2): <gurobi.Var g[i][t][44,2]>,
#  (44, 3): <gurobi.Var g[i][t][44,3]>,
#  (44, 4): <gurobi.Var g[i][t][44,4]>,
#  (44, 5): <gurobi.Var g[i][t][44,5]>,
#  (44, 6): <gurobi.Var g[i][t][44,6]>,
#  (45, 0): <gurobi.Var g[i][t][45,0]>,
#  (45, 1): <gurobi.Var g[i][t][45,1]>,
#  (45, 2): <gurobi.Var g[i][t][45,2]>,
#  (45, 3): <gurobi.Var g[i][t][45,3]>,
#  (45, 4): <gurobi.Var g[i][t][45,4]>,
#  (45, 5): <gurobi.Var g[i][t][45,5]>,
#  (45, 6): <gurobi.Var g[i][t][45,6]>,
#  (46, 0): <gurobi.Var g[i][t][46,0]>,
#  (46, 1): <gurobi.Var g[i][t][46,1]>,
#  (46, 2): <gurobi.Var g[i][t][46,2]>,
#  (46, 3): <gurobi.Var g[i][t][46,3]>,
#  (46, 4): <gurobi.Var g[i][t][46,4]>,
#  (46, 5): <gurobi.Var g[i][t][46,5]>,
#  (46, 6): <gurobi.Var g[i][t][46,6]>,
#  (47, 0): <gurobi.Var g[i][t][47,0]>,
#  (47, 1): <gurobi.Var g[i][t][47,1]>,
#  (47, 2): <gurobi.Var g[i][t][47,2]>,
#  (47, 3): <gurobi.Var g[i][t][47,3]>,
#  (47, 4): <gurobi.Var g[i][t][47,4]>,
#  (47, 5): <gurobi.Var g[i][t][47,5]>,
#  (47, 6): <gurobi.Var g[i][t][47,6]>,
#  (48, 0): <gurobi.Var g[i][t][48,0]>,
#  (48, 1): <gurobi.Var g[i][t][48,1]>,
#  (48, 2): <gurobi.Var g[i][t][48,2]>,
#  (48, 3): <gurobi.Var g[i][t][48,3]>,
#  (48, 4): <gurobi.Var g[i][t][48,4]>,
#  (48, 5): <gurobi.Var g[i][t][48,5]>,
#  (48, 6): <gurobi.Var g[i][t][48,6]>}

# %%
# Out:
# [array([6.32697202, 9.16006758, 5.86316648, 5.52832049, 7.64947743,
#         7.29103384, 7.30882451]),
#  array([3.29513311, 2.76224026, 1.75401078, 2.98984065, 2.68709035,
#         2.24707282, 1.90056459]),
#  array([0.54982914, 0.52032081, 0.60900535, 0.68193197, 0.58100119,
#         0.35739405, 0.45088232]),
#  array([4.46784599, 3.31758845, 4.88374436, 3.82403738, 3.94678954,
#         2.82686921, 3.43131661]),
#  array([3.09623187, 3.1557408 , 3.18685162, 2.42887922, 2.62333307,
#         3.65763021, 2.60008072]),
#  array([1.17031517, 1.31971228, 0.87529086, 0.87080095, 1.19813477,
#         1.68367911, 0.96392876]),
#  array([5.95858596, 7.57736326, 5.598887  , 5.57247538, 7.90327486,
#         9.57740567, 9.58798642]),
#  array([1.30935898, 1.35800591, 1.27626697, 1.86393428, 1.30347369,
#         1.31752364, 1.46520688]),
#  array([4.16508122, 4.48477385, 3.88667383, 6.50074774, 4.38854896,
#         6.29910731, 4.68203826]),
#  array([3.06137565, 2.50384277, 2.50496321, 2.67796641, 2.99287155,
#         2.41126814, 2.17985504]),
#  array([4.83793348, 5.82503284, 5.43150489, 4.5390027 , 5.4163685 ,
#         5.1519891 , 4.89791064]),
#  array([1.74672674, 2.4129056 , 1.27015045, 1.87210466, 1.73909093,
#         2.78693961, 1.97095401]),
#  array([3.43710389, 3.88131959, 2.26303672, 3.37652829, 3.37626088,
#         5.04263175, 2.88180713]),
#  array([2.99097923, 3.07460979, 3.77901659, 2.86725409, 2.44254529,
#         2.60657341, 3.17061366]),
#  array([1.75795607, 1.32185241, 2.63544926, 2.25078815, 2.75583245,
#         2.74524674, 3.23460322]),
#  array([0.91249862, 1.63511284, 1.08684895, 0.94463319, 0.87608567,
#         1.2415497 , 1.54491971]),
#  array([2.7196089 , 1.95492705, 2.77384162, 2.22448723, 2.20698497,
#         2.50324137, 2.60417043]),
#  array([2.30745238, 2.38816885, 2.87604425, 2.49997101, 2.31619263,
#         2.60479749, 3.21409617]),
#  array([0.66312208, 0.71723593, 0.89563484, 0.55920639, 0.69783468,
#         0.89682821, 0.51495929]),
#  array([3.19117402, 3.41556987, 3.19224529, 3.15548732, 4.41991314,
#         3.91151696, 2.42733021]),
#  array([5.19453321, 2.81237263, 4.03645255, 2.78277879, 3.61292785,
#         5.02093034, 4.54132264]),
#  array([7.13899901, 5.74560211, 7.52776183, 7.18490689, 7.50179747,
#         7.4519238 , 5.51508303]),
#  array([2.25422015, 2.67690826, 3.10444308, 1.98780448, 2.5700056 ,
#         2.75132792, 1.437445  ]),
#  array([0.81109709, 0.90117366, 0.82392552, 0.77837188, 0.59682914,
#         0.73880785, 0.66004983]),
#  array([1.18502317, 2.421612  , 3.69772889, 3.66175016, 2.94542844,
#         3.60335937, 3.19349745]),
#  array([0.66965987, 0.64874917, 0.75512996, 1.19114209, 1.25133721,
#         1.31079061, 0.80390115]),
#  array([2.61858715, 3.03114529, 2.25249508, 2.66424374, 3.68554279,
#         2.77961207, 3.13004209]),
#  array([3.44211464, 1.87837146, 2.02852915, 2.49871871, 1.9322072 ,
#         3.73741017, 2.91025521]),
#  array([0.90586825, 1.0383873 , 1.11136807, 0.73536422, 1.07172989,
#         1.04994318, 1.03202401]),
#  array([1.1558859 , 1.15083787, 1.02685725, 1.02490273, 1.06372722,
#         1.09849974, 1.0908865 ]),
#  array([1.32982574, 1.75120737, 1.17849722, 1.52922997, 1.48478271,
#         1.33269567, 1.13926521]),
#  array([2.95786295, 2.3899495 , 2.4184549 , 2.97967685, 3.47402115,
#         2.28948315, 2.77766644]),
#  array([0.73680788, 0.48168387, 0.6771053 , 0.78921905, 0.79615229,
#         0.83866714, 0.6586767 ]),
#  array([2.38118815, 2.39918634, 2.19807765, 2.66900677, 2.24073712,
#         2.27706692, 2.52421225]),
#  array([3.48218443, 3.05532326, 2.64139963, 3.23525062, 3.59730529,
#         3.66779457, 2.40579943]),
#  array([2.28123087, 3.43276794, 2.29654808, 4.12544808, 2.40193589,
#         2.42980645, 2.92205354]),
#  array([2.07442589, 1.85306605, 2.04874119, 3.10478799, 3.34731383,
#         2.57452152, 2.9197937 ]),
#  array([4.92047441, 8.14802485, 4.22118354, 6.05599374, 4.57301883,
#         4.43225955, 6.87803858]),
#  array([1.37120978, 1.34132283, 1.46797108, 1.67131544, 0.97242339,
#         0.89045264, 1.3869768 ]),
#  array([0.63443327, 0.6641705 , 0.8445083 , 0.70461941, 0.48000546,
#         0.77167545, 0.91471204]),
#  array([2.443563  , 1.10675711, 2.41170136, 1.96223047, 2.24535555,
#         2.07608925, 2.26349452]),
#  array([1.63598749, 2.36462608, 2.26616594, 2.3520188 , 2.85310304,
#         2.99260844, 1.63522015]),
#  array([0.26833129, 0.28718447, 0.24934236, 0.38193268, 0.32692588,
#         0.37669624, 0.37249198]),
#  array([3.72816695, 4.44864905, 3.96476179, 2.83106052, 5.06073915,
#         2.67997941, 4.82843798]),
#  array([4.08793451, 2.43794648, 3.64322841, 2.35922348, 3.15827567,
#         2.9800936 , 2.09911553]),
#  array([2.9530811 , 1.96504065, 3.29420561, 2.04384034, 1.49263787,
#         2.62410981, 2.62591674]),
#  array([1.48613483, 1.96719073, 2.62196522, 1.86607832, 2.14965985,
#         2.16270131, 1.14756898]),
#  array([1.93828905, 1.59966809, 1.58635225, 2.06416783, 2.18361291,
#         2.05784295, 1.81831408]),
#  array([0.30310326, 0.2206618 , 0.22088544, 0.30348343, 0.20610407,
#         0.16000831, 0.2871228 ])]

# %%
# model.setObjective(g_vars.prod({k: v for k,v in enumerate(c_list)}) + 10*s.sum('*'))
model.setObjective(sum(g_vars))

model.update()

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2170 rows, 2877 columns and 9513 nonzeros
# Model fingerprint: 0x8e8e61d3
# Variable types: 2527 continuous, 350 integer (7 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 1e+06]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 70.0000000
# Presolve removed 816 rows and 1493 columns
# Presolve time: 0.06s
# Presolved: 1354 rows, 1384 columns, 5589 nonzeros
# Variable types: 1378 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 1.000000e+01, 12 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      10.0000000   10.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.18 seconds (0.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 10 70
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%

# %%
np.max(model.getA())
# Out:
# 6770.6

# %%
# Initialize variables to track the largest coefficient
max_coefficient = 0
max_row = None
max_col = None

# Iterate through all constraints
for i, constr in enumerate(model.getConstrs()):
    row = model.getRow(constr)  # Sparse representation of constraint row
    for j in range(row.size()):
        coeff = row.getCoeff(j)
        if abs(coeff) > abs(max_coefficient):  # Update if this coefficient is larger
            max_coefficient = coeff
            max_row = i
            max_col = row.getVar(j).index

# %%
max_coefficient
# Out:
# -999999.0

# %%
max(recipes_transpose_csr_ish[1])
# Out:
# [2500.0, 454.0, 907.0, 450.0, 680.0, 680.0, 454.0]

# %%
print(model.getVarByName("r[j][t][0,0]"))
# Out:
# <gurobi.Var r[j][t][0,0] (value 42.75534441805225)>

# %%
model.getVarByName("s")

# %%
# for var in model.getVars():
#     print(var)
for var in model.getVars():
        if var.x != 0:
            print(var.varName, "=", var.x)
# Out:
# g[i][t][0,0] = 999999.0
# g[i][t][1,0] = 999999.0
# g[i][t][2,0] = 999999.0
# g[i][t][3,0] = 999999.0
# g[i][t][4,0] = 999999.0
# g[i][t][5,0] = 999999.0
# g[i][t][6,0] = 999999.0
# g[i][t][7,0] = 999999.0
# g[i][t][8,0] = 999999.0
# g[i][t][9,0] = 999999.0
# g[i][t][10,0] = 999999.0
# g[i][t][11,0] = 999999.0
# g[i][t][12,0] = 999999.0
# g[i][t][13,0] = 999999.0
# g[i][t][14,0] = 999999.0
# g[i][t][15,0] = 999999.0
# g[i][t][16,0] = 999999.0
# g[i][t][17,0] = 999999.0
# g[i][t][18,0] = 999999.0
# g[i][t][19,0] = 999999.0
# g[i][t][20,0] = 999999.0
# g[i][t][21,0] = 999999.0
# g[i][t][22,0] = 999999.0
# g[i][t][23,0] = 999999.0
# g[i][t][24,0] = 999999.0
# g[i][t][25,0] = 999999.0
# g[i][t][26,0] = 999999.0
# g[i][t][27,0] = 999999.0
# g[i][t][28,0] = 999999.0
# g[i][t][29,0] = 999999.0
# g[i][t][30,0] = 999999.0
# g[i][t][31,0] = 999999.0
# g[i][t][32,0] = 999999.0
# g[i][t][33,0] = 999999.0
# g[i][t][34,0] = 999999.0
# g[i][t][35,0] = 999999.0
# g[i][t][36,0] = 999999.0
# g[i][t][37,0] = 999999.0
# g[i][t][38,0] = 999999.0
# g[i][t][39,0] = 999999.0
# g[i][t][40,0] = 999999.0
# g[i][t][41,0] = 999999.0
# g[i][t][42,0] = 999999.0
# g[i][t][43,0] = 999999.0
# g[i][t][44,0] = 999999.0
# g[i][t][45,0] = 999999.0
# g[i][t][46,0] = 999999.0
# g[i][t][47,0] = 999999.0
# g[i][t][48,0] = 999999.0
# u[i][tau][t][0,0,0] = 29027.00711497992
# u[i][tau][t][1,0,0] = 11687.838569012536
# u[i][tau][t][2,0,0] = 11484.077083186252
# u[i][tau][t][3,0,0] = 10245.743743732124
# u[i][tau][t][3,0,1] = 4097.630500623552
# u[i][tau][t][3,0,2] = 4097.630500623552
# u[i][tau][t][3,0,3] = 4097.630500623552
# u[i][tau][t][3,0,4] = 4097.630500623552
# u[i][tau][t][3,0,5] = 4097.630500623552
# u[i][tau][t][3,0,6] = 4097.630500623552
# u[i][tau][t][4,0,0] = 10905.240999749609
# u[i][tau][t][5,0,0] = 469.2683773918669
# u[i][tau][t][6,0,0] = 21592.678989469117
# u[i][tau][t][7,0,0] = 323.85533434276056
# u[i][tau][t][8,0,0] = 34310.909497421235
# u[i][tau][t][9,0,0] = 2376.3824147701307
# u[i][tau][t][10,0,0] = 356.4573622155196
# u[i][tau][t][11,0,0] = 1782.286811077598
# u[i][tau][t][12,0,0] = 116555.90135820844
# u[i][tau][t][13,0,0] = 799.0807444384446
# u[i][tau][t][14,0,0] = 636962.6132686262
# u[i][tau][t][14,0,1] = 2622.483520399073
# u[i][tau][t][14,0,2] = 2622.483520399073
# u[i][tau][t][14,0,3] = 2622.483520399073
# u[i][tau][t][14,0,4] = 2622.483520399073
# u[i][tau][t][14,0,5] = 2622.483520399073
# u[i][tau][t][14,0,6] = 2622.483520399073
# u[i][tau][t][15,0,0] = 731.3667762199547
# u[i][tau][t][16,0,0] = 32615.45504539501
# u[i][tau][t][16,0,1] = 204.8815250311776
# u[i][tau][t][16,0,2] = 204.8815250311776
# u[i][tau][t][16,0,3] = 204.8815250311776
# u[i][tau][t][16,0,4] = 204.8815250311776
# u[i][tau][t][16,0,5] = 204.8815250311776
# u[i][tau][t][16,0,6] = 204.8815250311776
# u[i][tau][t][17,0,0] = 2632.3588249987415
# u[i][tau][t][17,0,1] = 131.12417601995367
# u[i][tau][t][17,0,2] = 131.12417601995367
# u[i][tau][t][17,0,3] = 131.12417601995367
# u[i][tau][t][17,0,4] = 131.12417601995367
# u[i][tau][t][17,0,5] = 131.12417601995367
# u[i][tau][t][17,0,6] = 131.12417601995367
# u[i][tau][t][18,0,0] = 3278.1044004988416
# u[i][tau][t][18,0,1] = 3278.1044004988416
# u[i][tau][t][18,0,2] = 3278.1044004988416
# u[i][tau][t][18,0,3] = 3278.1044004988416
# u[i][tau][t][18,0,4] = 3278.1044004988416
# u[i][tau][t][18,0,5] = 3278.1044004988416
# u[i][tau][t][18,0,6] = 3278.1044004988416
# u[i][tau][t][19,0,0] = 4247.213309345079
# u[i][tau][t][19,0,1] = 819.5261001247104
# u[i][tau][t][19,0,2] = 819.5261001247104
# u[i][tau][t][19,0,3] = 819.5261001247104
# u[i][tau][t][19,0,4] = 819.5261001247104
# u[i][tau][t][19,0,5] = 819.5261001247104
# u[i][tau][t][19,0,6] = 819.5261001247104
# u[i][tau][t][20,0,0] = 548.8802832759799
# u[i][tau][t][21,0,0] = 1354.2764115668147
# u[i][tau][t][22,0,0] = 49.63600264725348
# u[i][tau][t][23,0,0] = 2191.2753692433153
# u[i][tau][t][24,0,0] = 1265.3405148013812
# u[i][tau][t][25,0,0] = 92.36453201970443
# u[i][tau][t][26,0,0] = 554.1871921182266
# u[i][tau][t][27,0,0] = 221.90611664295875
# u[i][tau][t][28,0,0] = 227.06374882274994
# u[i][tau][t][29,0,0] = 4914.325815511975
# u[i][tau][t][30,0,0] = 205.18492582576266
# u[i][tau][t][31,0,0] = 1940.3525061838468
# u[i][tau][t][32,0,0] = 247.41072193308275
# u[i][tau][t][33,0,0] = 2001.0852247462594
# u[i][tau][t][34,0,0] = 132.0267574228377
# u[i][tau][t][35,0,0] = 669.0376075765316
# u[i][tau][t][36,0,0] = 3348.4649128073206
# u[i][tau][t][37,0,0] = 4227.238194783778
# u[i][tau][t][38,0,0] = 44.20953354029945
# u[i][tau][t][39,0,0] = 319.4979524518898
# u[i][tau][t][40,0,0] = 813.2793927513867
# u[i][tau][t][41,0,0] = 805.4947922295337
# u[i][tau][t][42,0,0] = 1347.4667222999103
# u[i][tau][t][43,0,0] = 258.1992609763375
# u[i][tau][t][44,0,0] = 48.19719538224966
# u[i][tau][t][45,0,0] = 194.51010993550756
# u[i][tau][t][46,0,0] = 671.9117900419227
# u[i][tau][t][47,0,0] = 517.9365408213677
# u[i][tau][t][48,0,0] = 189999810.0
# r[j][t][0,0] = 42.75534441805225
# r[j][t][1,0] = 2.8316270964931385
# r[j][t][2,0] = 11.881912073850653
# r[j][t][3,0] = 625.0
# r[j][t][4,0] = 16.390522002494208
# r[j][t][4,1] = 16.390522002494208
# r[j][t][4,2] = 16.390522002494208
# r[j][t][4,3] = 16.390522002494208
# r[j][t][4,4] = 16.390522002494208
# r[j][t][4,5] = 16.390522002494208
# r[j][t][4,6] = 16.390522002494208
# r[j][t][5,0] = 2.4692979575753595
# r[j][t][6,0] = 4.1363335539377895
# r[j][t][7,0] = 3.0788177339901477
# r[j][t][8,0] = 7.396870554765291
# r[j][t][9,0] = 4.40089191409459
# r[j][t][10,0] = 2.947302236019963
# r[j][t][11,0] = 5.421862618342578
# r[j][t][12,0] = 6.282124500285551
# r[j][t][13,0] = 1.7213284065089165
# r[j][t][14,0] = 7.465686556021364
# r[j][t][15,0] = 8.286984653141882
# r[j][t][16,0] = 9.809050483913156
# r[j][t][17,0] = 999999.0
# s[0] = 1.0

# %%
print(model.getVarByName("g[i][t][0,0]"))
# Out:
# <gurobi.Var g[i][t][0,0] (value 999999.0)>

# %%
# for constr in model.getConstrs():
#         lhs_value = sum(var.X * coeff for var, coeff in zip(model.getVars(), model.getRow(constr)))
#         print(f"Constraint {constr.ConstrName}: LHS = {lhs_value:.2f}, RHS = {constr.RHS:.2f}")

# %%
# print(model.getRows())

# print(model.getConstrs())

for constr in model.getConstrs():
        print(model.getRow(constr))
        print(constr.RHS)
# Out:
# 2035.92 r[j][t][0,0] + 6157.55 r[j][t][1,0] + 877.53 r[j][t][2,0] + 1215.88 r[j][t][3,0] + 1226.835 r[j][t][4,0] + 2205.895 r[j][t][5,0] + 4404.3 r[j][t][6,0] + 2465.93 r[j][t][7,0] + 1179.52 r[j][t][8,0] + 2404.32 r[j][t][9,0] + 1301.12 r[j][t][10,0] + 2137.04 r[j][t][11,0] + 1169.6100000000001 r[j][t][12,0] + 2744.5099999999998 r[j][t][13,0] + 1027.69 r[j][t][14,0] + 1588.365 r[j][t][15,0] + 4049.16 r[j][t][16,0] + 169.1 r[j][t][17,0]
# 3000.0
# 170.974 r[j][t][0,0] + 685.935 r[j][t][1,0] + 49.18600000000001 r[j][t][2,0] + 39.47 r[j][t][3,0] + 38.61000000000001 r[j][t][4,0] + 177.412 r[j][t][5,0] + 116.938 r[j][t][6,0] + 261.91200000000003 r[j][t][7,0] + 75.842 r[j][t][8,0] + 183.274 r[j][t][9,0] + 76.304 r[j][t][10,0] + 198.418 r[j][t][11,0] + 11.765 r[j][t][12,0] + 230.525 r[j][t][13,0] + 70.764 r[j][t][14,0] + 129.025 r[j][t][15,0] + 144.10399999999998 r[j][t][16,0] + 2.0900000000000003 r[j][t][17,0]
# 56.0
# 541.46 r[j][t][0,0] + 2059.15 r[j][t][1,0] + 2149.79 r[j][t][2,0] + 835.78 r[j][t][3,0] + 140.32500000000002 r[j][t][4,0] + 3862.51 r[j][t][5,0] + 2083.8 r[j][t][6,0] + 1288.03 r[j][t][7,0] + 2094.21 r[j][t][8,0] + 1140.06 r[j][t][9,0] + 1070.67 r[j][t][10,0] + 2373.58 r[j][t][11,0] + 2416.46 r[j][t][12,0] + 1363.78 r[j][t][13,0] + 1546.34 r[j][t][14,0] + 3554.775 r[j][t][15,0] + 3224.5099999999998 r[j][t][16,0] + 1.9000000000000001 r[j][t][17,0]
# 2300.0
# 3282.26 r[j][t][0,0] + 6770.6 r[j][t][1,0] + 1323.36 r[j][t][2,0] + 1593.32 r[j][t][3,0] + 819.23 r[j][t][4,0] + 1903.375 r[j][t][5,0] + 1482.16 r[j][t][6,0] + 4387.83 r[j][t][7,0] + 1823.44 r[j][t][8,0] + 4286.43 r[j][t][9,0] + 2629.31 r[j][t][10,0] + 2690.61 r[j][t][11,0] + 1781.9199999999998 r[j][t][12,0] + 3957.27 r[j][t][13,0] + 1802.3700000000001 r[j][t][14,0] + 1821.8275 r[j][t][15,0] + 2280.65 r[j][t][16,0] + 680.2 r[j][t][17,0]
# 4700.0
# 360.1 r[j][t][0,0] + 459.1 r[j][t][1,0] + 109.41 r[j][t][2,0] + 1320.82 r[j][t][3,0] + 354.78499999999997 r[j][t][4,0] + 1434.05 r[j][t][5,0] + 532.32 r[j][t][6,0] + 422.24 r[j][t][7,0] + 175.75 r[j][t][8,0] + 1455.53 r[j][t][9,0] + 1034.19 r[j][t][10,0] + 239.77 r[j][t][11,0] + 249.68 r[j][t][12,0] + 900.91 r[j][t][13,0] + 174.13 r[j][t][14,0] + 156.8725 r[j][t][15,0] + 828.59 r[j][t][16,0] + 9.5 r[j][t][17,0]
# 1300.0
# 187.76 r[j][t][0,0] + 686.3 r[j][t][1,0] + 265.28 r[j][t][2,0] + 135.01 r[j][t][3,0] + 92.4 r[j][t][4,0] + 212.0 r[j][t][5,0] + 223.25 r[j][t][6,0] + 343.21000000000004 r[j][t][7,0] + 162.9 r[j][t][8,0] + 345.79 r[j][t][9,0] + 273.22 r[j][t][10,0] + 267.34000000000003 r[j][t][11,0] + 162.16 r[j][t][12,0] + 578.1899999999999 r[j][t][13,0] + 131.55 r[j][t][14,0] + 165.35 r[j][t][15,0] + 241.10999999999999 r[j][t][16,0] + 51.300000000000004 r[j][t][17,0]
# 410.0
# 26.461 r[j][t][0,0] + 26.115 r[j][t][1,0] + 3.464 r[j][t][2,0] + 4.843 r[j][t][3,0] + 3.384 r[j][t][4,0] + 12.135 r[j][t][5,0] + 9.203 r[j][t][6,0] + 11.523 r[j][t][7,0] + 11.911 r[j][t][8,0] + 12.706 r[j][t][9,0] + 8.548 r[j][t][10,0] + 8.822 r[j][t][11,0] + 1.751 r[j][t][12,0] + 13.668000000000001 r[j][t][13,0] + 11.23 r[j][t][14,0] + 5.5325 r[j][t][15,0] + 9.56 r[j][t][16,0] + 0.28500000000000003 r[j][t][17,0]
# 11.0
# 17.756 r[j][t][0,0] + 31.1 r[j][t][1,0] + 7.25 r[j][t][2,0] + 0.745 r[j][t][3,0] + 4.7765 r[j][t][4,0] + 11.3575 r[j][t][5,0] + 13.403 r[j][t][6,0] + 14.23 r[j][t][7,0] + 10.401 r[j][t][8,0] + 14.741 r[j][t][9,0] + 16.086000000000002 r[j][t][10,0] + 10.664 r[j][t][11,0] + 6.922 r[j][t][12,0] + 16.666 r[j][t][13,0] + 9.04 r[j][t][14,0] + 7.3725000000000005 r[j][t][15,0] + 10.789000000000001 r[j][t][16,0] + 0.494 r[j][t][17,0]
# 11.0
# 21.05 r[j][t][0,0] + 536.6 r[j][t][1,0] + 190.76 r[j][t][2,0] + 812.6 r[j][t][3,0] + 254.39999999999998 r[j][t][4,0] + 804.095 r[j][t][5,0] + 680.0799999999999 r[j][t][6,0] + 363.19 r[j][t][7,0] + 449.01 r[j][t][8,0] + 1187.34 r[j][t][9,0] + 603.49 r[j][t][10,0] + 343.92 r[j][t][11,0] + 955.05 r[j][t][12,0] + 983.5 r[j][t][13,0] + 1151.52 r[j][t][14,0] + 248.91 r[j][t][15,0] + 2177.22 r[j][t][16,0] + 5.7 r[j][t][17,0]
# 900.0
# 134.7075 r[j][t][0,0] + 1.8665000000000003 r[j][t][1,0] + 0.4224 r[j][t][2,0] + 0.24180000000000001 r[j][t][3,0] + 0.3436 r[j][t][4,0] + 0.5129 r[j][t][5,0] + 0.9322 r[j][t][6,0] + 0.9980000000000001 r[j][t][7,0] + 0.5441 r[j][t][8,0] + 1.1137000000000001 r[j][t][9,0] + 1.2186000000000001 r[j][t][10,0] + 0.6628000000000001 r[j][t][11,0] + 0.5465 r[j][t][12,0] + 1.0993000000000002 r[j][t][13,0] + 0.6021000000000001 r[j][t][14,0] + 0.4953 r[j][t][15,0] + 161.63510000000002 r[j][t][16,0] + 0.0589 r[j][t][17,0]
# 1.2
# 2.0124 r[j][t][0,0] + 3.8545 r[j][t][1,0] + 0.9367 r[j][t][2,0] + 1.8642 r[j][t][3,0] + 0.6744 r[j][t][4,0] + 1.77865 r[j][t][5,0] + 1.5846 r[j][t][6,0] + 1.8953000000000002 r[j][t][7,0] + 0.6468 r[j][t][8,0] + 3.582 r[j][t][9,0] + 1.974 r[j][t][10,0] + 1.23 r[j][t][11,0] + 0.714 r[j][t][12,0] + 1.8118 r[j][t][13,0] + 0.6934 r[j][t][14,0] + 0.8099500000000001 r[j][t][15,0] + 2.2347 r[j][t][16,0] + 0.1387 r[j][t][17,0]
# 1.3
# 40.399 r[j][t][0,0] + 195.45 r[j][t][1,0] + 17.165000000000003 r[j][t][2,0] + 3.212 r[j][t][3,0] + 11.264 r[j][t][4,0] + 36.448499999999996 r[j][t][5,0] + 34.839999999999996 r[j][t][6,0] + 75.49499999999999 r[j][t][7,0] + 17.771 r[j][t][8,0] + 49.582 r[j][t][9,0] + 16.740000000000002 r[j][t][10,0] + 57.476 r[j][t][11,0] + 5.0649999999999995 r[j][t][12,0] + 64.128 r[j][t][13,0] + 15.742 r[j][t][14,0] + 36.506 r[j][t][15,0] + 33.769 r[j][t][16,0] + 1.2635 r[j][t][17,0]
# 16.0
# 2.8593 r[j][t][0,0] + 12.776 r[j][t][1,0] + 2.1601 r[j][t][2,0] + 0.6816000000000001 r[j][t][3,0] + 0.3732 r[j][t][4,0] + 2.7212 r[j][t][5,0] + 0.8328 r[j][t][6,0] + 5.2402 r[j][t][7,0] + 1.8547000000000002 r[j][t][8,0] + 3.6007000000000002 r[j][t][9,0] + 1.5184 r[j][t][10,0] + 4.0952 r[j][t][11,0] + 1.1985000000000001 r[j][t][12,0] + 4.5896 r[j][t][13,0] + 1.4354 r[j][t][14,0] + 2.8983 r[j][t][15,0] + 1.9913 r[j][t][16,0] + 0.6973 r[j][t][17,0]
# 1.3
# 13.759999999999998 r[j][t][0,0] + 7.75 r[j][t][1,0] + 24.0 r[j][t][2,0] + 4.0 r[j][t][3,0] + 1.085 r[j][t][4,0] + 3.8114 r[j][t][5,0] + 2.74 r[j][t][6,0] + 3.4777 r[j][t][7,0] + 5.175599999999999 r[j][t][8,0] + 5.234999999999999 r[j][t][9,0] + 6.0386 r[j][t][10,0] + 2.108 r[j][t][11,0] + 2.9330000000000003 r[j][t][13,0] + 5.175599999999999 r[j][t][14,0] + 1.4074 r[j][t][15,0] + 16.0644 r[j][t][16,0]
# 2.4
# 23.0 r[j][t][0,0] + 40.099999999999994 r[j][t][1,0] + 29.200000000000003 r[j][t][2,0] + 0.12 r[j][t][3,0] + 9.44 r[j][t][4,0] + 77.615 r[j][t][5,0] + 89.82799999999999 r[j][t][7,0] + 339.21000000000004 r[j][t][8,0] + 272.933 r[j][t][9,0] + 124.82 r[j][t][10,0] + 151.92200000000003 r[j][t][11,0] + 262.88 r[j][t][12,0] + 127.977 r[j][t][13,0] + 130.122 r[j][t][14,0] + 186.834 r[j][t][15,0] + 7.646000000000001 r[j][t][16,0] + 16.529999999999998 r[j][t][17,0]
# 75.0
# 2.4973 r[j][t][0,0] + 7.233 r[j][t][1,0] + 2.6038 r[j][t][2,0] + 1.6248 r[j][t][3,0] + 1.2686 r[j][t][4,0] + 7.0194 r[j][t][5,0] + 3.6264 r[j][t][6,0] + 6.2985 r[j][t][7,0] + 4.054 r[j][t][8,0] + 3.4084 r[j][t][9,0] + 5.0893999999999995 r[j][t][10,0] + 4.9201 r[j][t][11,0] + 14.644499999999999 r[j][t][12,0] + 8.7142 r[j][t][13,0] + 6.469399999999999 r[j][t][14,0] + 7.766274999999999 r[j][t][15,0] + 14.060599999999999 r[j][t][16,0] + 0.19 r[j][t][17,0]
# 15.0
# 2035.92 r[j][t][0,1] + 6157.55 r[j][t][1,1] + 877.53 r[j][t][2,1] + 1215.88 r[j][t][3,1] + 1226.835 r[j][t][4,1] + 2205.895 r[j][t][5,1] + 4404.3 r[j][t][6,1] + 2465.93 r[j][t][7,1] + 1179.52 r[j][t][8,1] + 2404.32 r[j][t][9,1] + 1301.12 r[j][t][10,1] + 2137.04 r[j][t][11,1] + 1169.6100000000001 r[j][t][12,1] + 2744.5099999999998 r[j][t][13,1] + 1027.69 r[j][t][14,1] + 1588.365 r[j][t][15,1] + 4049.16 r[j][t][16,1] + 169.1 r[j][t][17,1]
# 3000.0
# 170.974 r[j][t][0,1] + 685.935 r[j][t][1,1] + 49.18600000000001 r[j][t][2,1] + 39.47 r[j][t][3,1] + 38.61000000000001 r[j][t][4,1] + 177.412 r[j][t][5,1] + 116.938 r[j][t][6,1] + 261.91200000000003 r[j][t][7,1] + 75.842 r[j][t][8,1] + 183.274 r[j][t][9,1] + 76.304 r[j][t][10,1] + 198.418 r[j][t][11,1] + 11.765 r[j][t][12,1] + 230.525 r[j][t][13,1] + 70.764 r[j][t][14,1] + 129.025 r[j][t][15,1] + 144.10399999999998 r[j][t][16,1] + 2.0900000000000003 r[j][t][17,1]
# 56.0
# 541.46 r[j][t][0,1] + 2059.15 r[j][t][1,1] + 2149.79 r[j][t][2,1] + 835.78 r[j][t][3,1] + 140.32500000000002 r[j][t][4,1] + 3862.51 r[j][t][5,1] + 2083.8 r[j][t][6,1] + 1288.03 r[j][t][7,1] + 2094.21 r[j][t][8,1] + 1140.06 r[j][t][9,1] + 1070.67 r[j][t][10,1] + 2373.58 r[j][t][11,1] + 2416.46 r[j][t][12,1] + 1363.78 r[j][t][13,1] + 1546.34 r[j][t][14,1] + 3554.775 r[j][t][15,1] + 3224.5099999999998 r[j][t][16,1] + 1.9000000000000001 r[j][t][17,1]
# 2300.0
# 3282.26 r[j][t][0,1] + 6770.6 r[j][t][1,1] + 1323.36 r[j][t][2,1] + 1593.32 r[j][t][3,1] + 819.23 r[j][t][4,1] + 1903.375 r[j][t][5,1] + 1482.16 r[j][t][6,1] + 4387.83 r[j][t][7,1] + 1823.44 r[j][t][8,1] + 4286.43 r[j][t][9,1] + 2629.31 r[j][t][10,1] + 2690.61 r[j][t][11,1] + 1781.9199999999998 r[j][t][12,1] + 3957.27 r[j][t][13,1] + 1802.3700000000001 r[j][t][14,1] + 1821.8275 r[j][t][15,1] + 2280.65 r[j][t][16,1] + 680.2 r[j][t][17,1]
# 4700.0
# 360.1 r[j][t][0,1] + 459.1 r[j][t][1,1] + 109.41 r[j][t][2,1] + 1320.82 r[j][t][3,1] + 354.78499999999997 r[j][t][4,1] + 1434.05 r[j][t][5,1] + 532.32 r[j][t][6,1] + 422.24 r[j][t][7,1] + 175.75 r[j][t][8,1] + 1455.53 r[j][t][9,1] + 1034.19 r[j][t][10,1] + 239.77 r[j][t][11,1] + 249.68 r[j][t][12,1] + 900.91 r[j][t][13,1] + 174.13 r[j][t][14,1] + 156.8725 r[j][t][15,1] + 828.59 r[j][t][16,1] + 9.5 r[j][t][17,1]
# 1300.0
# 187.76 r[j][t][0,1] + 686.3 r[j][t][1,1] + 265.28 r[j][t][2,1] + 135.01 r[j][t][3,1] + 92.4 r[j][t][4,1] + 212.0 r[j][t][5,1] + 223.25 r[j][t][6,1] + 343.21000000000004 r[j][t][7,1] + 162.9 r[j][t][8,1] + 345.79 r[j][t][9,1] + 273.22 r[j][t][10,1] + 267.34000000000003 r[j][t][11,1] + 162.16 r[j][t][12,1] + 578.1899999999999 r[j][t][13,1] + 131.55 r[j][t][14,1] + 165.35 r[j][t][15,1] + 241.10999999999999 r[j][t][16,1] + 51.300000000000004 r[j][t][17,1]
# 410.0
# 26.461 r[j][t][0,1] + 26.115 r[j][t][1,1] + 3.464 r[j][t][2,1] + 4.843 r[j][t][3,1] + 3.384 r[j][t][4,1] + 12.135 r[j][t][5,1] + 9.203 r[j][t][6,1] + 11.523 r[j][t][7,1] + 11.911 r[j][t][8,1] + 12.706 r[j][t][9,1] + 8.548 r[j][t][10,1] + 8.822 r[j][t][11,1] + 1.751 r[j][t][12,1] + 13.668000000000001 r[j][t][13,1] + 11.23 r[j][t][14,1] + 5.5325 r[j][t][15,1] + 9.56 r[j][t][16,1] + 0.28500000000000003 r[j][t][17,1]
# 11.0
# 17.756 r[j][t][0,1] + 31.1 r[j][t][1,1] + 7.25 r[j][t][2,1] + 0.745 r[j][t][3,1] + 4.7765 r[j][t][4,1] + 11.3575 r[j][t][5,1] + 13.403 r[j][t][6,1] + 14.23 r[j][t][7,1] + 10.401 r[j][t][8,1] + 14.741 r[j][t][9,1] + 16.086000000000002 r[j][t][10,1] + 10.664 r[j][t][11,1] + 6.922 r[j][t][12,1] + 16.666 r[j][t][13,1] + 9.04 r[j][t][14,1] + 7.3725000000000005 r[j][t][15,1] + 10.789000000000001 r[j][t][16,1] + 0.494 r[j][t][17,1]
# 11.0
# 21.05 r[j][t][0,1] + 536.6 r[j][t][1,1] + 190.76 r[j][t][2,1] + 812.6 r[j][t][3,1] + 254.39999999999998 r[j][t][4,1] + 804.095 r[j][t][5,1] + 680.0799999999999 r[j][t][6,1] + 363.19 r[j][t][7,1] + 449.01 r[j][t][8,1] + 1187.34 r[j][t][9,1] + 603.49 r[j][t][10,1] + 343.92 r[j][t][11,1] + 955.05 r[j][t][12,1] + 983.5 r[j][t][13,1] + 1151.52 r[j][t][14,1] + 248.91 r[j][t][15,1] + 2177.22 r[j][t][16,1] + 5.7 r[j][t][17,1]
# 900.0
# 134.7075 r[j][t][0,1] + 1.8665000000000003 r[j][t][1,1] + 0.4224 r[j][t][2,1] + 0.24180000000000001 r[j][t][3,1] + 0.3436 r[j][t][4,1] + 0.5129 r[j][t][5,1] + 0.9322 r[j][t][6,1] + 0.9980000000000001 r[j][t][7,1] + 0.5441 r[j][t][8,1] + 1.1137000000000001 r[j][t][9,1] + 1.2186000000000001 r[j][t][10,1] + 0.6628000000000001 r[j][t][11,1] + 0.5465 r[j][t][12,1] + 1.0993000000000002 r[j][t][13,1] + 0.6021000000000001 r[j][t][14,1] + 0.4953 r[j][t][15,1] + 161.63510000000002 r[j][t][16,1] + 0.0589 r[j][t][17,1]
# 1.2
# 2.0124 r[j][t][0,1] + 3.8545 r[j][t][1,1] + 0.9367 r[j][t][2,1] + 1.8642 r[j][t][3,1] + 0.6744 r[j][t][4,1] + 1.77865 r[j][t][5,1] + 1.5846 r[j][t][6,1] + 1.8953000000000002 r[j][t][7,1] + 0.6468 r[j][t][8,1] + 3.582 r[j][t][9,1] + 1.974 r[j][t][10,1] + 1.23 r[j][t][11,1] + 0.714 r[j][t][12,1] + 1.8118 r[j][t][13,1] + 0.6934 r[j][t][14,1] + 0.8099500000000001 r[j][t][15,1] + 2.2347 r[j][t][16,1] + 0.1387 r[j][t][17,1]
# 1.3
# 40.399 r[j][t][0,1] + 195.45 r[j][t][1,1] + 17.165000000000003 r[j][t][2,1] + 3.212 r[j][t][3,1] + 11.264 r[j][t][4,1] + 36.448499999999996 r[j][t][5,1] + 34.839999999999996 r[j][t][6,1] + 75.49499999999999 r[j][t][7,1] + 17.771 r[j][t][8,1] + 49.582 r[j][t][9,1] + 16.740000000000002 r[j][t][10,1] + 57.476 r[j][t][11,1] + 5.0649999999999995 r[j][t][12,1] + 64.128 r[j][t][13,1] + 15.742 r[j][t][14,1] + 36.506 r[j][t][15,1] + 33.769 r[j][t][16,1] + 1.2635 r[j][t][17,1]
# 16.0
# 2.8593 r[j][t][0,1] + 12.776 r[j][t][1,1] + 2.1601 r[j][t][2,1] + 0.6816000000000001 r[j][t][3,1] + 0.3732 r[j][t][4,1] + 2.7212 r[j][t][5,1] + 0.8328 r[j][t][6,1] + 5.2402 r[j][t][7,1] + 1.8547000000000002 r[j][t][8,1] + 3.6007000000000002 r[j][t][9,1] + 1.5184 r[j][t][10,1] + 4.0952 r[j][t][11,1] + 1.1985000000000001 r[j][t][12,1] + 4.5896 r[j][t][13,1] + 1.4354 r[j][t][14,1] + 2.8983 r[j][t][15,1] + 1.9913 r[j][t][16,1] + 0.6973 r[j][t][17,1]
# 1.3
# 13.759999999999998 r[j][t][0,1] + 7.75 r[j][t][1,1] + 24.0 r[j][t][2,1] + 4.0 r[j][t][3,1] + 1.085 r[j][t][4,1] + 3.8114 r[j][t][5,1] + 2.74 r[j][t][6,1] + 3.4777 r[j][t][7,1] + 5.175599999999999 r[j][t][8,1] + 5.234999999999999 r[j][t][9,1] + 6.0386 r[j][t][10,1] + 2.108 r[j][t][11,1] + 2.9330000000000003 r[j][t][13,1] + 5.175599999999999 r[j][t][14,1] + 1.4074 r[j][t][15,1] + 16.0644 r[j][t][16,1]
# 2.4
# 23.0 r[j][t][0,1] + 40.099999999999994 r[j][t][1,1] + 29.200000000000003 r[j][t][2,1] + 0.12 r[j][t][3,1] + 9.44 r[j][t][4,1] + 77.615 r[j][t][5,1] + 89.82799999999999 r[j][t][7,1] + 339.21000000000004 r[j][t][8,1] + 272.933 r[j][t][9,1] + 124.82 r[j][t][10,1] + 151.92200000000003 r[j][t][11,1] + 262.88 r[j][t][12,1] + 127.977 r[j][t][13,1] + 130.122 r[j][t][14,1] + 186.834 r[j][t][15,1] + 7.646000000000001 r[j][t][16,1] + 16.529999999999998 r[j][t][17,1]
# 75.0
# 2.4973 r[j][t][0,1] + 7.233 r[j][t][1,1] + 2.6038 r[j][t][2,1] + 1.6248 r[j][t][3,1] + 1.2686 r[j][t][4,1] + 7.0194 r[j][t][5,1] + 3.6264 r[j][t][6,1] + 6.2985 r[j][t][7,1] + 4.054 r[j][t][8,1] + 3.4084 r[j][t][9,1] + 5.0893999999999995 r[j][t][10,1] + 4.9201 r[j][t][11,1] + 14.644499999999999 r[j][t][12,1] + 8.7142 r[j][t][13,1] + 6.469399999999999 r[j][t][14,1] + 7.766274999999999 r[j][t][15,1] + 14.060599999999999 r[j][t][16,1] + 0.19 r[j][t][17,1]
# 15.0
# 2035.92 r[j][t][0,2] + 6157.55 r[j][t][1,2] + 877.53 r[j][t][2,2] + 1215.88 r[j][t][3,2] + 1226.835 r[j][t][4,2] + 2205.895 r[j][t][5,2] + 4404.3 r[j][t][6,2] + 2465.93 r[j][t][7,2] + 1179.52 r[j][t][8,2] + 2404.32 r[j][t][9,2] + 1301.12 r[j][t][10,2] + 2137.04 r[j][t][11,2] + 1169.6100000000001 r[j][t][12,2] + 2744.5099999999998 r[j][t][13,2] + 1027.69 r[j][t][14,2] + 1588.365 r[j][t][15,2] + 4049.16 r[j][t][16,2] + 169.1 r[j][t][17,2]
# 3000.0
# 170.974 r[j][t][0,2] + 685.935 r[j][t][1,2] + 49.18600000000001 r[j][t][2,2] + 39.47 r[j][t][3,2] + 38.61000000000001 r[j][t][4,2] + 177.412 r[j][t][5,2] + 116.938 r[j][t][6,2] + 261.91200000000003 r[j][t][7,2] + 75.842 r[j][t][8,2] + 183.274 r[j][t][9,2] + 76.304 r[j][t][10,2] + 198.418 r[j][t][11,2] + 11.765 r[j][t][12,2] + 230.525 r[j][t][13,2] + 70.764 r[j][t][14,2] + 129.025 r[j][t][15,2] + 144.10399999999998 r[j][t][16,2] + 2.0900000000000003 r[j][t][17,2]
# 56.0
# 541.46 r[j][t][0,2] + 2059.15 r[j][t][1,2] + 2149.79 r[j][t][2,2] + 835.78 r[j][t][3,2] + 140.32500000000002 r[j][t][4,2] + 3862.51 r[j][t][5,2] + 2083.8 r[j][t][6,2] + 1288.03 r[j][t][7,2] + 2094.21 r[j][t][8,2] + 1140.06 r[j][t][9,2] + 1070.67 r[j][t][10,2] + 2373.58 r[j][t][11,2] + 2416.46 r[j][t][12,2] + 1363.78 r[j][t][13,2] + 1546.34 r[j][t][14,2] + 3554.775 r[j][t][15,2] + 3224.5099999999998 r[j][t][16,2] + 1.9000000000000001 r[j][t][17,2]
# 2300.0
# 3282.26 r[j][t][0,2] + 6770.6 r[j][t][1,2] + 1323.36 r[j][t][2,2] + 1593.32 r[j][t][3,2] + 819.23 r[j][t][4,2] + 1903.375 r[j][t][5,2] + 1482.16 r[j][t][6,2] + 4387.83 r[j][t][7,2] + 1823.44 r[j][t][8,2] + 4286.43 r[j][t][9,2] + 2629.31 r[j][t][10,2] + 2690.61 r[j][t][11,2] + 1781.9199999999998 r[j][t][12,2] + 3957.27 r[j][t][13,2] + 1802.3700000000001 r[j][t][14,2] + 1821.8275 r[j][t][15,2] + 2280.65 r[j][t][16,2] + 680.2 r[j][t][17,2]
# 4700.0
# 360.1 r[j][t][0,2] + 459.1 r[j][t][1,2] + 109.41 r[j][t][2,2] + 1320.82 r[j][t][3,2] + 354.78499999999997 r[j][t][4,2] + 1434.05 r[j][t][5,2] + 532.32 r[j][t][6,2] + 422.24 r[j][t][7,2] + 175.75 r[j][t][8,2] + 1455.53 r[j][t][9,2] + 1034.19 r[j][t][10,2] + 239.77 r[j][t][11,2] + 249.68 r[j][t][12,2] + 900.91 r[j][t][13,2] + 174.13 r[j][t][14,2] + 156.8725 r[j][t][15,2] + 828.59 r[j][t][16,2] + 9.5 r[j][t][17,2]
# 1300.0
# 187.76 r[j][t][0,2] + 686.3 r[j][t][1,2] + 265.28 r[j][t][2,2] + 135.01 r[j][t][3,2] + 92.4 r[j][t][4,2] + 212.0 r[j][t][5,2] + 223.25 r[j][t][6,2] + 343.21000000000004 r[j][t][7,2] + 162.9 r[j][t][8,2] + 345.79 r[j][t][9,2] + 273.22 r[j][t][10,2] + 267.34000000000003 r[j][t][11,2] + 162.16 r[j][t][12,2] + 578.1899999999999 r[j][t][13,2] + 131.55 r[j][t][14,2] + 165.35 r[j][t][15,2] + 241.10999999999999 r[j][t][16,2] + 51.300000000000004 r[j][t][17,2]
# 410.0
# 26.461 r[j][t][0,2] + 26.115 r[j][t][1,2] + 3.464 r[j][t][2,2] + 4.843 r[j][t][3,2] + 3.384 r[j][t][4,2] + 12.135 r[j][t][5,2] + 9.203 r[j][t][6,2] + 11.523 r[j][t][7,2] + 11.911 r[j][t][8,2] + 12.706 r[j][t][9,2] + 8.548 r[j][t][10,2] + 8.822 r[j][t][11,2] + 1.751 r[j][t][12,2] + 13.668000000000001 r[j][t][13,2] + 11.23 r[j][t][14,2] + 5.5325 r[j][t][15,2] + 9.56 r[j][t][16,2] + 0.28500000000000003 r[j][t][17,2]
# 11.0
# 17.756 r[j][t][0,2] + 31.1 r[j][t][1,2] + 7.25 r[j][t][2,2] + 0.745 r[j][t][3,2] + 4.7765 r[j][t][4,2] + 11.3575 r[j][t][5,2] + 13.403 r[j][t][6,2] + 14.23 r[j][t][7,2] + 10.401 r[j][t][8,2] + 14.741 r[j][t][9,2] + 16.086000000000002 r[j][t][10,2] + 10.664 r[j][t][11,2] + 6.922 r[j][t][12,2] + 16.666 r[j][t][13,2] + 9.04 r[j][t][14,2] + 7.3725000000000005 r[j][t][15,2] + 10.789000000000001 r[j][t][16,2] + 0.494 r[j][t][17,2]
# 11.0
# 21.05 r[j][t][0,2] + 536.6 r[j][t][1,2] + 190.76 r[j][t][2,2] + 812.6 r[j][t][3,2] + 254.39999999999998 r[j][t][4,2] + 804.095 r[j][t][5,2] + 680.0799999999999 r[j][t][6,2] + 363.19 r[j][t][7,2] + 449.01 r[j][t][8,2] + 1187.34 r[j][t][9,2] + 603.49 r[j][t][10,2] + 343.92 r[j][t][11,2] + 955.05 r[j][t][12,2] + 983.5 r[j][t][13,2] + 1151.52 r[j][t][14,2] + 248.91 r[j][t][15,2] + 2177.22 r[j][t][16,2] + 5.7 r[j][t][17,2]
# 900.0
# 134.7075 r[j][t][0,2] + 1.8665000000000003 r[j][t][1,2] + 0.4224 r[j][t][2,2] + 0.24180000000000001 r[j][t][3,2] + 0.3436 r[j][t][4,2] + 0.5129 r[j][t][5,2] + 0.9322 r[j][t][6,2] + 0.9980000000000001 r[j][t][7,2] + 0.5441 r[j][t][8,2] + 1.1137000000000001 r[j][t][9,2] + 1.2186000000000001 r[j][t][10,2] + 0.6628000000000001 r[j][t][11,2] + 0.5465 r[j][t][12,2] + 1.0993000000000002 r[j][t][13,2] + 0.6021000000000001 r[j][t][14,2] + 0.4953 r[j][t][15,2] + 161.63510000000002 r[j][t][16,2] + 0.0589 r[j][t][17,2]
# 1.2
# 2.0124 r[j][t][0,2] + 3.8545 r[j][t][1,2] + 0.9367 r[j][t][2,2] + 1.8642 r[j][t][3,2] + 0.6744 r[j][t][4,2] + 1.77865 r[j][t][5,2] + 1.5846 r[j][t][6,2] + 1.8953000000000002 r[j][t][7,2] + 0.6468 r[j][t][8,2] + 3.582 r[j][t][9,2] + 1.974 r[j][t][10,2] + 1.23 r[j][t][11,2] + 0.714 r[j][t][12,2] + 1.8118 r[j][t][13,2] + 0.6934 r[j][t][14,2] + 0.8099500000000001 r[j][t][15,2] + 2.2347 r[j][t][16,2] + 0.1387 r[j][t][17,2]
# 1.3
# 40.399 r[j][t][0,2] + 195.45 r[j][t][1,2] + 17.165000000000003 r[j][t][2,2] + 3.212 r[j][t][3,2] + 11.264 r[j][t][4,2] + 36.448499999999996 r[j][t][5,2] + 34.839999999999996 r[j][t][6,2] + 75.49499999999999 r[j][t][7,2] + 17.771 r[j][t][8,2] + 49.582 r[j][t][9,2] + 16.740000000000002 r[j][t][10,2] + 57.476 r[j][t][11,2] + 5.0649999999999995 r[j][t][12,2] + 64.128 r[j][t][13,2] + 15.742 r[j][t][14,2] + 36.506 r[j][t][15,2] + 33.769 r[j][t][16,2] + 1.2635 r[j][t][17,2]
# 16.0
# 2.8593 r[j][t][0,2] + 12.776 r[j][t][1,2] + 2.1601 r[j][t][2,2] + 0.6816000000000001 r[j][t][3,2] + 0.3732 r[j][t][4,2] + 2.7212 r[j][t][5,2] + 0.8328 r[j][t][6,2] + 5.2402 r[j][t][7,2] + 1.8547000000000002 r[j][t][8,2] + 3.6007000000000002 r[j][t][9,2] + 1.5184 r[j][t][10,2] + 4.0952 r[j][t][11,2] + 1.1985000000000001 r[j][t][12,2] + 4.5896 r[j][t][13,2] + 1.4354 r[j][t][14,2] + 2.8983 r[j][t][15,2] + 1.9913 r[j][t][16,2] + 0.6973 r[j][t][17,2]
# 1.3
# 13.759999999999998 r[j][t][0,2] + 7.75 r[j][t][1,2] + 24.0 r[j][t][2,2] + 4.0 r[j][t][3,2] + 1.085 r[j][t][4,2] + 3.8114 r[j][t][5,2] + 2.74 r[j][t][6,2] + 3.4777 r[j][t][7,2] + 5.175599999999999 r[j][t][8,2] + 5.234999999999999 r[j][t][9,2] + 6.0386 r[j][t][10,2] + 2.108 r[j][t][11,2] + 2.9330000000000003 r[j][t][13,2] + 5.175599999999999 r[j][t][14,2] + 1.4074 r[j][t][15,2] + 16.0644 r[j][t][16,2]
# 2.4
# 23.0 r[j][t][0,2] + 40.099999999999994 r[j][t][1,2] + 29.200000000000003 r[j][t][2,2] + 0.12 r[j][t][3,2] + 9.44 r[j][t][4,2] + 77.615 r[j][t][5,2] + 89.82799999999999 r[j][t][7,2] + 339.21000000000004 r[j][t][8,2] + 272.933 r[j][t][9,2] + 124.82 r[j][t][10,2] + 151.92200000000003 r[j][t][11,2] + 262.88 r[j][t][12,2] + 127.977 r[j][t][13,2] + 130.122 r[j][t][14,2] + 186.834 r[j][t][15,2] + 7.646000000000001 r[j][t][16,2] + 16.529999999999998 r[j][t][17,2]
# 75.0
# 2.4973 r[j][t][0,2] + 7.233 r[j][t][1,2] + 2.6038 r[j][t][2,2] + 1.6248 r[j][t][3,2] + 1.2686 r[j][t][4,2] + 7.0194 r[j][t][5,2] + 3.6264 r[j][t][6,2] + 6.2985 r[j][t][7,2] + 4.054 r[j][t][8,2] + 3.4084 r[j][t][9,2] + 5.0893999999999995 r[j][t][10,2] + 4.9201 r[j][t][11,2] + 14.644499999999999 r[j][t][12,2] + 8.7142 r[j][t][13,2] + 6.469399999999999 r[j][t][14,2] + 7.766274999999999 r[j][t][15,2] + 14.060599999999999 r[j][t][16,2] + 0.19 r[j][t][17,2]
# 15.0
# 2035.92 r[j][t][0,3] + 6157.55 r[j][t][1,3] + 877.53 r[j][t][2,3] + 1215.88 r[j][t][3,3] + 1226.835 r[j][t][4,3] + 2205.895 r[j][t][5,3] + 4404.3 r[j][t][6,3] + 2465.93 r[j][t][7,3] + 1179.52 r[j][t][8,3] + 2404.32 r[j][t][9,3] + 1301.12 r[j][t][10,3] + 2137.04 r[j][t][11,3] + 1169.6100000000001 r[j][t][12,3] + 2744.5099999999998 r[j][t][13,3] + 1027.69 r[j][t][14,3] + 1588.365 r[j][t][15,3] + 4049.16 r[j][t][16,3] + 169.1 r[j][t][17,3]
# 3000.0
# 170.974 r[j][t][0,3] + 685.935 r[j][t][1,3] + 49.18600000000001 r[j][t][2,3] + 39.47 r[j][t][3,3] + 38.61000000000001 r[j][t][4,3] + 177.412 r[j][t][5,3] + 116.938 r[j][t][6,3] + 261.91200000000003 r[j][t][7,3] + 75.842 r[j][t][8,3] + 183.274 r[j][t][9,3] + 76.304 r[j][t][10,3] + 198.418 r[j][t][11,3] + 11.765 r[j][t][12,3] + 230.525 r[j][t][13,3] + 70.764 r[j][t][14,3] + 129.025 r[j][t][15,3] + 144.10399999999998 r[j][t][16,3] + 2.0900000000000003 r[j][t][17,3]
# 56.0
# 541.46 r[j][t][0,3] + 2059.15 r[j][t][1,3] + 2149.79 r[j][t][2,3] + 835.78 r[j][t][3,3] + 140.32500000000002 r[j][t][4,3] + 3862.51 r[j][t][5,3] + 2083.8 r[j][t][6,3] + 1288.03 r[j][t][7,3] + 2094.21 r[j][t][8,3] + 1140.06 r[j][t][9,3] + 1070.67 r[j][t][10,3] + 2373.58 r[j][t][11,3] + 2416.46 r[j][t][12,3] + 1363.78 r[j][t][13,3] + 1546.34 r[j][t][14,3] + 3554.775 r[j][t][15,3] + 3224.5099999999998 r[j][t][16,3] + 1.9000000000000001 r[j][t][17,3]
# 2300.0
# 3282.26 r[j][t][0,3] + 6770.6 r[j][t][1,3] + 1323.36 r[j][t][2,3] + 1593.32 r[j][t][3,3] + 819.23 r[j][t][4,3] + 1903.375 r[j][t][5,3] + 1482.16 r[j][t][6,3] + 4387.83 r[j][t][7,3] + 1823.44 r[j][t][8,3] + 4286.43 r[j][t][9,3] + 2629.31 r[j][t][10,3] + 2690.61 r[j][t][11,3] + 1781.9199999999998 r[j][t][12,3] + 3957.27 r[j][t][13,3] + 1802.3700000000001 r[j][t][14,3] + 1821.8275 r[j][t][15,3] + 2280.65 r[j][t][16,3] + 680.2 r[j][t][17,3]
# 4700.0
# 360.1 r[j][t][0,3] + 459.1 r[j][t][1,3] + 109.41 r[j][t][2,3] + 1320.82 r[j][t][3,3] + 354.78499999999997 r[j][t][4,3] + 1434.05 r[j][t][5,3] + 532.32 r[j][t][6,3] + 422.24 r[j][t][7,3] + 175.75 r[j][t][8,3] + 1455.53 r[j][t][9,3] + 1034.19 r[j][t][10,3] + 239.77 r[j][t][11,3] + 249.68 r[j][t][12,3] + 900.91 r[j][t][13,3] + 174.13 r[j][t][14,3] + 156.8725 r[j][t][15,3] + 828.59 r[j][t][16,3] + 9.5 r[j][t][17,3]
# 1300.0
# 187.76 r[j][t][0,3] + 686.3 r[j][t][1,3] + 265.28 r[j][t][2,3] + 135.01 r[j][t][3,3] + 92.4 r[j][t][4,3] + 212.0 r[j][t][5,3] + 223.25 r[j][t][6,3] + 343.21000000000004 r[j][t][7,3] + 162.9 r[j][t][8,3] + 345.79 r[j][t][9,3] + 273.22 r[j][t][10,3] + 267.34000000000003 r[j][t][11,3] + 162.16 r[j][t][12,3] + 578.1899999999999 r[j][t][13,3] + 131.55 r[j][t][14,3] + 165.35 r[j][t][15,3] + 241.10999999999999 r[j][t][16,3] + 51.300000000000004 r[j][t][17,3]
# 410.0
# 26.461 r[j][t][0,3] + 26.115 r[j][t][1,3] + 3.464 r[j][t][2,3] + 4.843 r[j][t][3,3] + 3.384 r[j][t][4,3] + 12.135 r[j][t][5,3] + 9.203 r[j][t][6,3] + 11.523 r[j][t][7,3] + 11.911 r[j][t][8,3] + 12.706 r[j][t][9,3] + 8.548 r[j][t][10,3] + 8.822 r[j][t][11,3] + 1.751 r[j][t][12,3] + 13.668000000000001 r[j][t][13,3] + 11.23 r[j][t][14,3] + 5.5325 r[j][t][15,3] + 9.56 r[j][t][16,3] + 0.28500000000000003 r[j][t][17,3]
# 11.0
# 17.756 r[j][t][0,3] + 31.1 r[j][t][1,3] + 7.25 r[j][t][2,3] + 0.745 r[j][t][3,3] + 4.7765 r[j][t][4,3] + 11.3575 r[j][t][5,3] + 13.403 r[j][t][6,3] + 14.23 r[j][t][7,3] + 10.401 r[j][t][8,3] + 14.741 r[j][t][9,3] + 16.086000000000002 r[j][t][10,3] + 10.664 r[j][t][11,3] + 6.922 r[j][t][12,3] + 16.666 r[j][t][13,3] + 9.04 r[j][t][14,3] + 7.3725000000000005 r[j][t][15,3] + 10.789000000000001 r[j][t][16,3] + 0.494 r[j][t][17,3]
# 11.0
# 21.05 r[j][t][0,3] + 536.6 r[j][t][1,3] + 190.76 r[j][t][2,3] + 812.6 r[j][t][3,3] + 254.39999999999998 r[j][t][4,3] + 804.095 r[j][t][5,3] + 680.0799999999999 r[j][t][6,3] + 363.19 r[j][t][7,3] + 449.01 r[j][t][8,3] + 1187.34 r[j][t][9,3] + 603.49 r[j][t][10,3] + 343.92 r[j][t][11,3] + 955.05 r[j][t][12,3] + 983.5 r[j][t][13,3] + 1151.52 r[j][t][14,3] + 248.91 r[j][t][15,3] + 2177.22 r[j][t][16,3] + 5.7 r[j][t][17,3]
# 900.0
# 134.7075 r[j][t][0,3] + 1.8665000000000003 r[j][t][1,3] + 0.4224 r[j][t][2,3] + 0.24180000000000001 r[j][t][3,3] + 0.3436 r[j][t][4,3] + 0.5129 r[j][t][5,3] + 0.9322 r[j][t][6,3] + 0.9980000000000001 r[j][t][7,3] + 0.5441 r[j][t][8,3] + 1.1137000000000001 r[j][t][9,3] + 1.2186000000000001 r[j][t][10,3] + 0.6628000000000001 r[j][t][11,3] + 0.5465 r[j][t][12,3] + 1.0993000000000002 r[j][t][13,3] + 0.6021000000000001 r[j][t][14,3] + 0.4953 r[j][t][15,3] + 161.63510000000002 r[j][t][16,3] + 0.0589 r[j][t][17,3]
# 1.2
# 2.0124 r[j][t][0,3] + 3.8545 r[j][t][1,3] + 0.9367 r[j][t][2,3] + 1.8642 r[j][t][3,3] + 0.6744 r[j][t][4,3] + 1.77865 r[j][t][5,3] + 1.5846 r[j][t][6,3] + 1.8953000000000002 r[j][t][7,3] + 0.6468 r[j][t][8,3] + 3.582 r[j][t][9,3] + 1.974 r[j][t][10,3] + 1.23 r[j][t][11,3] + 0.714 r[j][t][12,3] + 1.8118 r[j][t][13,3] + 0.6934 r[j][t][14,3] + 0.8099500000000001 r[j][t][15,3] + 2.2347 r[j][t][16,3] + 0.1387 r[j][t][17,3]
# 1.3
# 40.399 r[j][t][0,3] + 195.45 r[j][t][1,3] + 17.165000000000003 r[j][t][2,3] + 3.212 r[j][t][3,3] + 11.264 r[j][t][4,3] + 36.448499999999996 r[j][t][5,3] + 34.839999999999996 r[j][t][6,3] + 75.49499999999999 r[j][t][7,3] + 17.771 r[j][t][8,3] + 49.582 r[j][t][9,3] + 16.740000000000002 r[j][t][10,3] + 57.476 r[j][t][11,3] + 5.0649999999999995 r[j][t][12,3] + 64.128 r[j][t][13,3] + 15.742 r[j][t][14,3] + 36.506 r[j][t][15,3] + 33.769 r[j][t][16,3] + 1.2635 r[j][t][17,3]
# 16.0
# 2.8593 r[j][t][0,3] + 12.776 r[j][t][1,3] + 2.1601 r[j][t][2,3] + 0.6816000000000001 r[j][t][3,3] + 0.3732 r[j][t][4,3] + 2.7212 r[j][t][5,3] + 0.8328 r[j][t][6,3] + 5.2402 r[j][t][7,3] + 1.8547000000000002 r[j][t][8,3] + 3.6007000000000002 r[j][t][9,3] + 1.5184 r[j][t][10,3] + 4.0952 r[j][t][11,3] + 1.1985000000000001 r[j][t][12,3] + 4.5896 r[j][t][13,3] + 1.4354 r[j][t][14,3] + 2.8983 r[j][t][15,3] + 1.9913 r[j][t][16,3] + 0.6973 r[j][t][17,3]
# 1.3
# 13.759999999999998 r[j][t][0,3] + 7.75 r[j][t][1,3] + 24.0 r[j][t][2,3] + 4.0 r[j][t][3,3] + 1.085 r[j][t][4,3] + 3.8114 r[j][t][5,3] + 2.74 r[j][t][6,3] + 3.4777 r[j][t][7,3] + 5.175599999999999 r[j][t][8,3] + 5.234999999999999 r[j][t][9,3] + 6.0386 r[j][t][10,3] + 2.108 r[j][t][11,3] + 2.9330000000000003 r[j][t][13,3] + 5.175599999999999 r[j][t][14,3] + 1.4074 r[j][t][15,3] + 16.0644 r[j][t][16,3]
# 2.4
# 23.0 r[j][t][0,3] + 40.099999999999994 r[j][t][1,3] + 29.200000000000003 r[j][t][2,3] + 0.12 r[j][t][3,3] + 9.44 r[j][t][4,3] + 77.615 r[j][t][5,3] + 89.82799999999999 r[j][t][7,3] + 339.21000000000004 r[j][t][8,3] + 272.933 r[j][t][9,3] + 124.82 r[j][t][10,3] + 151.92200000000003 r[j][t][11,3] + 262.88 r[j][t][12,3] + 127.977 r[j][t][13,3] + 130.122 r[j][t][14,3] + 186.834 r[j][t][15,3] + 7.646000000000001 r[j][t][16,3] + 16.529999999999998 r[j][t][17,3]
# 75.0
# 2.4973 r[j][t][0,3] + 7.233 r[j][t][1,3] + 2.6038 r[j][t][2,3] + 1.6248 r[j][t][3,3] + 1.2686 r[j][t][4,3] + 7.0194 r[j][t][5,3] + 3.6264 r[j][t][6,3] + 6.2985 r[j][t][7,3] + 4.054 r[j][t][8,3] + 3.4084 r[j][t][9,3] + 5.0893999999999995 r[j][t][10,3] + 4.9201 r[j][t][11,3] + 14.644499999999999 r[j][t][12,3] + 8.7142 r[j][t][13,3] + 6.469399999999999 r[j][t][14,3] + 7.766274999999999 r[j][t][15,3] + 14.060599999999999 r[j][t][16,3] + 0.19 r[j][t][17,3]
# 15.0
# 2035.92 r[j][t][0,4] + 6157.55 r[j][t][1,4] + 877.53 r[j][t][2,4] + 1215.88 r[j][t][3,4] + 1226.835 r[j][t][4,4] + 2205.895 r[j][t][5,4] + 4404.3 r[j][t][6,4] + 2465.93 r[j][t][7,4] + 1179.52 r[j][t][8,4] + 2404.32 r[j][t][9,4] + 1301.12 r[j][t][10,4] + 2137.04 r[j][t][11,4] + 1169.6100000000001 r[j][t][12,4] + 2744.5099999999998 r[j][t][13,4] + 1027.69 r[j][t][14,4] + 1588.365 r[j][t][15,4] + 4049.16 r[j][t][16,4] + 169.1 r[j][t][17,4]
# 3000.0
# 170.974 r[j][t][0,4] + 685.935 r[j][t][1,4] + 49.18600000000001 r[j][t][2,4] + 39.47 r[j][t][3,4] + 38.61000000000001 r[j][t][4,4] + 177.412 r[j][t][5,4] + 116.938 r[j][t][6,4] + 261.91200000000003 r[j][t][7,4] + 75.842 r[j][t][8,4] + 183.274 r[j][t][9,4] + 76.304 r[j][t][10,4] + 198.418 r[j][t][11,4] + 11.765 r[j][t][12,4] + 230.525 r[j][t][13,4] + 70.764 r[j][t][14,4] + 129.025 r[j][t][15,4] + 144.10399999999998 r[j][t][16,4] + 2.0900000000000003 r[j][t][17,4]
# 56.0
# 541.46 r[j][t][0,4] + 2059.15 r[j][t][1,4] + 2149.79 r[j][t][2,4] + 835.78 r[j][t][3,4] + 140.32500000000002 r[j][t][4,4] + 3862.51 r[j][t][5,4] + 2083.8 r[j][t][6,4] + 1288.03 r[j][t][7,4] + 2094.21 r[j][t][8,4] + 1140.06 r[j][t][9,4] + 1070.67 r[j][t][10,4] + 2373.58 r[j][t][11,4] + 2416.46 r[j][t][12,4] + 1363.78 r[j][t][13,4] + 1546.34 r[j][t][14,4] + 3554.775 r[j][t][15,4] + 3224.5099999999998 r[j][t][16,4] + 1.9000000000000001 r[j][t][17,4]
# 2300.0
# 3282.26 r[j][t][0,4] + 6770.6 r[j][t][1,4] + 1323.36 r[j][t][2,4] + 1593.32 r[j][t][3,4] + 819.23 r[j][t][4,4] + 1903.375 r[j][t][5,4] + 1482.16 r[j][t][6,4] + 4387.83 r[j][t][7,4] + 1823.44 r[j][t][8,4] + 4286.43 r[j][t][9,4] + 2629.31 r[j][t][10,4] + 2690.61 r[j][t][11,4] + 1781.9199999999998 r[j][t][12,4] + 3957.27 r[j][t][13,4] + 1802.3700000000001 r[j][t][14,4] + 1821.8275 r[j][t][15,4] + 2280.65 r[j][t][16,4] + 680.2 r[j][t][17,4]
# 4700.0
# 360.1 r[j][t][0,4] + 459.1 r[j][t][1,4] + 109.41 r[j][t][2,4] + 1320.82 r[j][t][3,4] + 354.78499999999997 r[j][t][4,4] + 1434.05 r[j][t][5,4] + 532.32 r[j][t][6,4] + 422.24 r[j][t][7,4] + 175.75 r[j][t][8,4] + 1455.53 r[j][t][9,4] + 1034.19 r[j][t][10,4] + 239.77 r[j][t][11,4] + 249.68 r[j][t][12,4] + 900.91 r[j][t][13,4] + 174.13 r[j][t][14,4] + 156.8725 r[j][t][15,4] + 828.59 r[j][t][16,4] + 9.5 r[j][t][17,4]
# 1300.0
# 187.76 r[j][t][0,4] + 686.3 r[j][t][1,4] + 265.28 r[j][t][2,4] + 135.01 r[j][t][3,4] + 92.4 r[j][t][4,4] + 212.0 r[j][t][5,4] + 223.25 r[j][t][6,4] + 343.21000000000004 r[j][t][7,4] + 162.9 r[j][t][8,4] + 345.79 r[j][t][9,4] + 273.22 r[j][t][10,4] + 267.34000000000003 r[j][t][11,4] + 162.16 r[j][t][12,4] + 578.1899999999999 r[j][t][13,4] + 131.55 r[j][t][14,4] + 165.35 r[j][t][15,4] + 241.10999999999999 r[j][t][16,4] + 51.300000000000004 r[j][t][17,4]
# 410.0
# 26.461 r[j][t][0,4] + 26.115 r[j][t][1,4] + 3.464 r[j][t][2,4] + 4.843 r[j][t][3,4] + 3.384 r[j][t][4,4] + 12.135 r[j][t][5,4] + 9.203 r[j][t][6,4] + 11.523 r[j][t][7,4] + 11.911 r[j][t][8,4] + 12.706 r[j][t][9,4] + 8.548 r[j][t][10,4] + 8.822 r[j][t][11,4] + 1.751 r[j][t][12,4] + 13.668000000000001 r[j][t][13,4] + 11.23 r[j][t][14,4] + 5.5325 r[j][t][15,4] + 9.56 r[j][t][16,4] + 0.28500000000000003 r[j][t][17,4]
# 11.0
# 17.756 r[j][t][0,4] + 31.1 r[j][t][1,4] + 7.25 r[j][t][2,4] + 0.745 r[j][t][3,4] + 4.7765 r[j][t][4,4] + 11.3575 r[j][t][5,4] + 13.403 r[j][t][6,4] + 14.23 r[j][t][7,4] + 10.401 r[j][t][8,4] + 14.741 r[j][t][9,4] + 16.086000000000002 r[j][t][10,4] + 10.664 r[j][t][11,4] + 6.922 r[j][t][12,4] + 16.666 r[j][t][13,4] + 9.04 r[j][t][14,4] + 7.3725000000000005 r[j][t][15,4] + 10.789000000000001 r[j][t][16,4] + 0.494 r[j][t][17,4]
# 11.0
# 21.05 r[j][t][0,4] + 536.6 r[j][t][1,4] + 190.76 r[j][t][2,4] + 812.6 r[j][t][3,4] + 254.39999999999998 r[j][t][4,4] + 804.095 r[j][t][5,4] + 680.0799999999999 r[j][t][6,4] + 363.19 r[j][t][7,4] + 449.01 r[j][t][8,4] + 1187.34 r[j][t][9,4] + 603.49 r[j][t][10,4] + 343.92 r[j][t][11,4] + 955.05 r[j][t][12,4] + 983.5 r[j][t][13,4] + 1151.52 r[j][t][14,4] + 248.91 r[j][t][15,4] + 2177.22 r[j][t][16,4] + 5.7 r[j][t][17,4]
# 900.0
# 134.7075 r[j][t][0,4] + 1.8665000000000003 r[j][t][1,4] + 0.4224 r[j][t][2,4] + 0.24180000000000001 r[j][t][3,4] + 0.3436 r[j][t][4,4] + 0.5129 r[j][t][5,4] + 0.9322 r[j][t][6,4] + 0.9980000000000001 r[j][t][7,4] + 0.5441 r[j][t][8,4] + 1.1137000000000001 r[j][t][9,4] + 1.2186000000000001 r[j][t][10,4] + 0.6628000000000001 r[j][t][11,4] + 0.5465 r[j][t][12,4] + 1.0993000000000002 r[j][t][13,4] + 0.6021000000000001 r[j][t][14,4] + 0.4953 r[j][t][15,4] + 161.63510000000002 r[j][t][16,4] + 0.0589 r[j][t][17,4]
# 1.2
# 2.0124 r[j][t][0,4] + 3.8545 r[j][t][1,4] + 0.9367 r[j][t][2,4] + 1.8642 r[j][t][3,4] + 0.6744 r[j][t][4,4] + 1.77865 r[j][t][5,4] + 1.5846 r[j][t][6,4] + 1.8953000000000002 r[j][t][7,4] + 0.6468 r[j][t][8,4] + 3.582 r[j][t][9,4] + 1.974 r[j][t][10,4] + 1.23 r[j][t][11,4] + 0.714 r[j][t][12,4] + 1.8118 r[j][t][13,4] + 0.6934 r[j][t][14,4] + 0.8099500000000001 r[j][t][15,4] + 2.2347 r[j][t][16,4] + 0.1387 r[j][t][17,4]
# 1.3
# 40.399 r[j][t][0,4] + 195.45 r[j][t][1,4] + 17.165000000000003 r[j][t][2,4] + 3.212 r[j][t][3,4] + 11.264 r[j][t][4,4] + 36.448499999999996 r[j][t][5,4] + 34.839999999999996 r[j][t][6,4] + 75.49499999999999 r[j][t][7,4] + 17.771 r[j][t][8,4] + 49.582 r[j][t][9,4] + 16.740000000000002 r[j][t][10,4] + 57.476 r[j][t][11,4] + 5.0649999999999995 r[j][t][12,4] + 64.128 r[j][t][13,4] + 15.742 r[j][t][14,4] + 36.506 r[j][t][15,4] + 33.769 r[j][t][16,4] + 1.2635 r[j][t][17,4]
# 16.0
# 2.8593 r[j][t][0,4] + 12.776 r[j][t][1,4] + 2.1601 r[j][t][2,4] + 0.6816000000000001 r[j][t][3,4] + 0.3732 r[j][t][4,4] + 2.7212 r[j][t][5,4] + 0.8328 r[j][t][6,4] + 5.2402 r[j][t][7,4] + 1.8547000000000002 r[j][t][8,4] + 3.6007000000000002 r[j][t][9,4] + 1.5184 r[j][t][10,4] + 4.0952 r[j][t][11,4] + 1.1985000000000001 r[j][t][12,4] + 4.5896 r[j][t][13,4] + 1.4354 r[j][t][14,4] + 2.8983 r[j][t][15,4] + 1.9913 r[j][t][16,4] + 0.6973 r[j][t][17,4]
# 1.3
# 13.759999999999998 r[j][t][0,4] + 7.75 r[j][t][1,4] + 24.0 r[j][t][2,4] + 4.0 r[j][t][3,4] + 1.085 r[j][t][4,4] + 3.8114 r[j][t][5,4] + 2.74 r[j][t][6,4] + 3.4777 r[j][t][7,4] + 5.175599999999999 r[j][t][8,4] + 5.234999999999999 r[j][t][9,4] + 6.0386 r[j][t][10,4] + 2.108 r[j][t][11,4] + 2.9330000000000003 r[j][t][13,4] + 5.175599999999999 r[j][t][14,4] + 1.4074 r[j][t][15,4] + 16.0644 r[j][t][16,4]
# 2.4
# 23.0 r[j][t][0,4] + 40.099999999999994 r[j][t][1,4] + 29.200000000000003 r[j][t][2,4] + 0.12 r[j][t][3,4] + 9.44 r[j][t][4,4] + 77.615 r[j][t][5,4] + 89.82799999999999 r[j][t][7,4] + 339.21000000000004 r[j][t][8,4] + 272.933 r[j][t][9,4] + 124.82 r[j][t][10,4] + 151.92200000000003 r[j][t][11,4] + 262.88 r[j][t][12,4] + 127.977 r[j][t][13,4] + 130.122 r[j][t][14,4] + 186.834 r[j][t][15,4] + 7.646000000000001 r[j][t][16,4] + 16.529999999999998 r[j][t][17,4]
# 75.0
# 2.4973 r[j][t][0,4] + 7.233 r[j][t][1,4] + 2.6038 r[j][t][2,4] + 1.6248 r[j][t][3,4] + 1.2686 r[j][t][4,4] + 7.0194 r[j][t][5,4] + 3.6264 r[j][t][6,4] + 6.2985 r[j][t][7,4] + 4.054 r[j][t][8,4] + 3.4084 r[j][t][9,4] + 5.0893999999999995 r[j][t][10,4] + 4.9201 r[j][t][11,4] + 14.644499999999999 r[j][t][12,4] + 8.7142 r[j][t][13,4] + 6.469399999999999 r[j][t][14,4] + 7.766274999999999 r[j][t][15,4] + 14.060599999999999 r[j][t][16,4] + 0.19 r[j][t][17,4]
# 15.0
# 2035.92 r[j][t][0,5] + 6157.55 r[j][t][1,5] + 877.53 r[j][t][2,5] + 1215.88 r[j][t][3,5] + 1226.835 r[j][t][4,5] + 2205.895 r[j][t][5,5] + 4404.3 r[j][t][6,5] + 2465.93 r[j][t][7,5] + 1179.52 r[j][t][8,5] + 2404.32 r[j][t][9,5] + 1301.12 r[j][t][10,5] + 2137.04 r[j][t][11,5] + 1169.6100000000001 r[j][t][12,5] + 2744.5099999999998 r[j][t][13,5] + 1027.69 r[j][t][14,5] + 1588.365 r[j][t][15,5] + 4049.16 r[j][t][16,5] + 169.1 r[j][t][17,5]
# 3000.0
# 170.974 r[j][t][0,5] + 685.935 r[j][t][1,5] + 49.18600000000001 r[j][t][2,5] + 39.47 r[j][t][3,5] + 38.61000000000001 r[j][t][4,5] + 177.412 r[j][t][5,5] + 116.938 r[j][t][6,5] + 261.91200000000003 r[j][t][7,5] + 75.842 r[j][t][8,5] + 183.274 r[j][t][9,5] + 76.304 r[j][t][10,5] + 198.418 r[j][t][11,5] + 11.765 r[j][t][12,5] + 230.525 r[j][t][13,5] + 70.764 r[j][t][14,5] + 129.025 r[j][t][15,5] + 144.10399999999998 r[j][t][16,5] + 2.0900000000000003 r[j][t][17,5]
# 56.0
# 541.46 r[j][t][0,5] + 2059.15 r[j][t][1,5] + 2149.79 r[j][t][2,5] + 835.78 r[j][t][3,5] + 140.32500000000002 r[j][t][4,5] + 3862.51 r[j][t][5,5] + 2083.8 r[j][t][6,5] + 1288.03 r[j][t][7,5] + 2094.21 r[j][t][8,5] + 1140.06 r[j][t][9,5] + 1070.67 r[j][t][10,5] + 2373.58 r[j][t][11,5] + 2416.46 r[j][t][12,5] + 1363.78 r[j][t][13,5] + 1546.34 r[j][t][14,5] + 3554.775 r[j][t][15,5] + 3224.5099999999998 r[j][t][16,5] + 1.9000000000000001 r[j][t][17,5]
# 2300.0
# 3282.26 r[j][t][0,5] + 6770.6 r[j][t][1,5] + 1323.36 r[j][t][2,5] + 1593.32 r[j][t][3,5] + 819.23 r[j][t][4,5] + 1903.375 r[j][t][5,5] + 1482.16 r[j][t][6,5] + 4387.83 r[j][t][7,5] + 1823.44 r[j][t][8,5] + 4286.43 r[j][t][9,5] + 2629.31 r[j][t][10,5] + 2690.61 r[j][t][11,5] + 1781.9199999999998 r[j][t][12,5] + 3957.27 r[j][t][13,5] + 1802.3700000000001 r[j][t][14,5] + 1821.8275 r[j][t][15,5] + 2280.65 r[j][t][16,5] + 680.2 r[j][t][17,5]
# 4700.0
# 360.1 r[j][t][0,5] + 459.1 r[j][t][1,5] + 109.41 r[j][t][2,5] + 1320.82 r[j][t][3,5] + 354.78499999999997 r[j][t][4,5] + 1434.05 r[j][t][5,5] + 532.32 r[j][t][6,5] + 422.24 r[j][t][7,5] + 175.75 r[j][t][8,5] + 1455.53 r[j][t][9,5] + 1034.19 r[j][t][10,5] + 239.77 r[j][t][11,5] + 249.68 r[j][t][12,5] + 900.91 r[j][t][13,5] + 174.13 r[j][t][14,5] + 156.8725 r[j][t][15,5] + 828.59 r[j][t][16,5] + 9.5 r[j][t][17,5]
# 1300.0
# 187.76 r[j][t][0,5] + 686.3 r[j][t][1,5] + 265.28 r[j][t][2,5] + 135.01 r[j][t][3,5] + 92.4 r[j][t][4,5] + 212.0 r[j][t][5,5] + 223.25 r[j][t][6,5] + 343.21000000000004 r[j][t][7,5] + 162.9 r[j][t][8,5] + 345.79 r[j][t][9,5] + 273.22 r[j][t][10,5] + 267.34000000000003 r[j][t][11,5] + 162.16 r[j][t][12,5] + 578.1899999999999 r[j][t][13,5] + 131.55 r[j][t][14,5] + 165.35 r[j][t][15,5] + 241.10999999999999 r[j][t][16,5] + 51.300000000000004 r[j][t][17,5]
# 410.0
# 26.461 r[j][t][0,5] + 26.115 r[j][t][1,5] + 3.464 r[j][t][2,5] + 4.843 r[j][t][3,5] + 3.384 r[j][t][4,5] + 12.135 r[j][t][5,5] + 9.203 r[j][t][6,5] + 11.523 r[j][t][7,5] + 11.911 r[j][t][8,5] + 12.706 r[j][t][9,5] + 8.548 r[j][t][10,5] + 8.822 r[j][t][11,5] + 1.751 r[j][t][12,5] + 13.668000000000001 r[j][t][13,5] + 11.23 r[j][t][14,5] + 5.5325 r[j][t][15,5] + 9.56 r[j][t][16,5] + 0.28500000000000003 r[j][t][17,5]
# 11.0
# 17.756 r[j][t][0,5] + 31.1 r[j][t][1,5] + 7.25 r[j][t][2,5] + 0.745 r[j][t][3,5] + 4.7765 r[j][t][4,5] + 11.3575 r[j][t][5,5] + 13.403 r[j][t][6,5] + 14.23 r[j][t][7,5] + 10.401 r[j][t][8,5] + 14.741 r[j][t][9,5] + 16.086000000000002 r[j][t][10,5] + 10.664 r[j][t][11,5] + 6.922 r[j][t][12,5] + 16.666 r[j][t][13,5] + 9.04 r[j][t][14,5] + 7.3725000000000005 r[j][t][15,5] + 10.789000000000001 r[j][t][16,5] + 0.494 r[j][t][17,5]
# 11.0
# 21.05 r[j][t][0,5] + 536.6 r[j][t][1,5] + 190.76 r[j][t][2,5] + 812.6 r[j][t][3,5] + 254.39999999999998 r[j][t][4,5] + 804.095 r[j][t][5,5] + 680.0799999999999 r[j][t][6,5] + 363.19 r[j][t][7,5] + 449.01 r[j][t][8,5] + 1187.34 r[j][t][9,5] + 603.49 r[j][t][10,5] + 343.92 r[j][t][11,5] + 955.05 r[j][t][12,5] + 983.5 r[j][t][13,5] + 1151.52 r[j][t][14,5] + 248.91 r[j][t][15,5] + 2177.22 r[j][t][16,5] + 5.7 r[j][t][17,5]
# 900.0
# 134.7075 r[j][t][0,5] + 1.8665000000000003 r[j][t][1,5] + 0.4224 r[j][t][2,5] + 0.24180000000000001 r[j][t][3,5] + 0.3436 r[j][t][4,5] + 0.5129 r[j][t][5,5] + 0.9322 r[j][t][6,5] + 0.9980000000000001 r[j][t][7,5] + 0.5441 r[j][t][8,5] + 1.1137000000000001 r[j][t][9,5] + 1.2186000000000001 r[j][t][10,5] + 0.6628000000000001 r[j][t][11,5] + 0.5465 r[j][t][12,5] + 1.0993000000000002 r[j][t][13,5] + 0.6021000000000001 r[j][t][14,5] + 0.4953 r[j][t][15,5] + 161.63510000000002 r[j][t][16,5] + 0.0589 r[j][t][17,5]
# 1.2
# 2.0124 r[j][t][0,5] + 3.8545 r[j][t][1,5] + 0.9367 r[j][t][2,5] + 1.8642 r[j][t][3,5] + 0.6744 r[j][t][4,5] + 1.77865 r[j][t][5,5] + 1.5846 r[j][t][6,5] + 1.8953000000000002 r[j][t][7,5] + 0.6468 r[j][t][8,5] + 3.582 r[j][t][9,5] + 1.974 r[j][t][10,5] + 1.23 r[j][t][11,5] + 0.714 r[j][t][12,5] + 1.8118 r[j][t][13,5] + 0.6934 r[j][t][14,5] + 0.8099500000000001 r[j][t][15,5] + 2.2347 r[j][t][16,5] + 0.1387 r[j][t][17,5]
# 1.3
# 40.399 r[j][t][0,5] + 195.45 r[j][t][1,5] + 17.165000000000003 r[j][t][2,5] + 3.212 r[j][t][3,5] + 11.264 r[j][t][4,5] + 36.448499999999996 r[j][t][5,5] + 34.839999999999996 r[j][t][6,5] + 75.49499999999999 r[j][t][7,5] + 17.771 r[j][t][8,5] + 49.582 r[j][t][9,5] + 16.740000000000002 r[j][t][10,5] + 57.476 r[j][t][11,5] + 5.0649999999999995 r[j][t][12,5] + 64.128 r[j][t][13,5] + 15.742 r[j][t][14,5] + 36.506 r[j][t][15,5] + 33.769 r[j][t][16,5] + 1.2635 r[j][t][17,5]
# 16.0
# 2.8593 r[j][t][0,5] + 12.776 r[j][t][1,5] + 2.1601 r[j][t][2,5] + 0.6816000000000001 r[j][t][3,5] + 0.3732 r[j][t][4,5] + 2.7212 r[j][t][5,5] + 0.8328 r[j][t][6,5] + 5.2402 r[j][t][7,5] + 1.8547000000000002 r[j][t][8,5] + 3.6007000000000002 r[j][t][9,5] + 1.5184 r[j][t][10,5] + 4.0952 r[j][t][11,5] + 1.1985000000000001 r[j][t][12,5] + 4.5896 r[j][t][13,5] + 1.4354 r[j][t][14,5] + 2.8983 r[j][t][15,5] + 1.9913 r[j][t][16,5] + 0.6973 r[j][t][17,5]
# 1.3
# 13.759999999999998 r[j][t][0,5] + 7.75 r[j][t][1,5] + 24.0 r[j][t][2,5] + 4.0 r[j][t][3,5] + 1.085 r[j][t][4,5] + 3.8114 r[j][t][5,5] + 2.74 r[j][t][6,5] + 3.4777 r[j][t][7,5] + 5.175599999999999 r[j][t][8,5] + 5.234999999999999 r[j][t][9,5] + 6.0386 r[j][t][10,5] + 2.108 r[j][t][11,5] + 2.9330000000000003 r[j][t][13,5] + 5.175599999999999 r[j][t][14,5] + 1.4074 r[j][t][15,5] + 16.0644 r[j][t][16,5]
# 2.4
# 23.0 r[j][t][0,5] + 40.099999999999994 r[j][t][1,5] + 29.200000000000003 r[j][t][2,5] + 0.12 r[j][t][3,5] + 9.44 r[j][t][4,5] + 77.615 r[j][t][5,5] + 89.82799999999999 r[j][t][7,5] + 339.21000000000004 r[j][t][8,5] + 272.933 r[j][t][9,5] + 124.82 r[j][t][10,5] + 151.92200000000003 r[j][t][11,5] + 262.88 r[j][t][12,5] + 127.977 r[j][t][13,5] + 130.122 r[j][t][14,5] + 186.834 r[j][t][15,5] + 7.646000000000001 r[j][t][16,5] + 16.529999999999998 r[j][t][17,5]
# 75.0
# 2.4973 r[j][t][0,5] + 7.233 r[j][t][1,5] + 2.6038 r[j][t][2,5] + 1.6248 r[j][t][3,5] + 1.2686 r[j][t][4,5] + 7.0194 r[j][t][5,5] + 3.6264 r[j][t][6,5] + 6.2985 r[j][t][7,5] + 4.054 r[j][t][8,5] + 3.4084 r[j][t][9,5] + 5.0893999999999995 r[j][t][10,5] + 4.9201 r[j][t][11,5] + 14.644499999999999 r[j][t][12,5] + 8.7142 r[j][t][13,5] + 6.469399999999999 r[j][t][14,5] + 7.766274999999999 r[j][t][15,5] + 14.060599999999999 r[j][t][16,5] + 0.19 r[j][t][17,5]
# 15.0
# 2035.92 r[j][t][0,6] + 6157.55 r[j][t][1,6] + 877.53 r[j][t][2,6] + 1215.88 r[j][t][3,6] + 1226.835 r[j][t][4,6] + 2205.895 r[j][t][5,6] + 4404.3 r[j][t][6,6] + 2465.93 r[j][t][7,6] + 1179.52 r[j][t][8,6] + 2404.32 r[j][t][9,6] + 1301.12 r[j][t][10,6] + 2137.04 r[j][t][11,6] + 1169.6100000000001 r[j][t][12,6] + 2744.5099999999998 r[j][t][13,6] + 1027.69 r[j][t][14,6] + 1588.365 r[j][t][15,6] + 4049.16 r[j][t][16,6] + 169.1 r[j][t][17,6]
# 3000.0
# 170.974 r[j][t][0,6] + 685.935 r[j][t][1,6] + 49.18600000000001 r[j][t][2,6] + 39.47 r[j][t][3,6] + 38.61000000000001 r[j][t][4,6] + 177.412 r[j][t][5,6] + 116.938 r[j][t][6,6] + 261.91200000000003 r[j][t][7,6] + 75.842 r[j][t][8,6] + 183.274 r[j][t][9,6] + 76.304 r[j][t][10,6] + 198.418 r[j][t][11,6] + 11.765 r[j][t][12,6] + 230.525 r[j][t][13,6] + 70.764 r[j][t][14,6] + 129.025 r[j][t][15,6] + 144.10399999999998 r[j][t][16,6] + 2.0900000000000003 r[j][t][17,6]
# 56.0
# 541.46 r[j][t][0,6] + 2059.15 r[j][t][1,6] + 2149.79 r[j][t][2,6] + 835.78 r[j][t][3,6] + 140.32500000000002 r[j][t][4,6] + 3862.51 r[j][t][5,6] + 2083.8 r[j][t][6,6] + 1288.03 r[j][t][7,6] + 2094.21 r[j][t][8,6] + 1140.06 r[j][t][9,6] + 1070.67 r[j][t][10,6] + 2373.58 r[j][t][11,6] + 2416.46 r[j][t][12,6] + 1363.78 r[j][t][13,6] + 1546.34 r[j][t][14,6] + 3554.775 r[j][t][15,6] + 3224.5099999999998 r[j][t][16,6] + 1.9000000000000001 r[j][t][17,6]
# 2300.0
# 3282.26 r[j][t][0,6] + 6770.6 r[j][t][1,6] + 1323.36 r[j][t][2,6] + 1593.32 r[j][t][3,6] + 819.23 r[j][t][4,6] + 1903.375 r[j][t][5,6] + 1482.16 r[j][t][6,6] + 4387.83 r[j][t][7,6] + 1823.44 r[j][t][8,6] + 4286.43 r[j][t][9,6] + 2629.31 r[j][t][10,6] + 2690.61 r[j][t][11,6] + 1781.9199999999998 r[j][t][12,6] + 3957.27 r[j][t][13,6] + 1802.3700000000001 r[j][t][14,6] + 1821.8275 r[j][t][15,6] + 2280.65 r[j][t][16,6] + 680.2 r[j][t][17,6]
# 4700.0
# 360.1 r[j][t][0,6] + 459.1 r[j][t][1,6] + 109.41 r[j][t][2,6] + 1320.82 r[j][t][3,6] + 354.78499999999997 r[j][t][4,6] + 1434.05 r[j][t][5,6] + 532.32 r[j][t][6,6] + 422.24 r[j][t][7,6] + 175.75 r[j][t][8,6] + 1455.53 r[j][t][9,6] + 1034.19 r[j][t][10,6] + 239.77 r[j][t][11,6] + 249.68 r[j][t][12,6] + 900.91 r[j][t][13,6] + 174.13 r[j][t][14,6] + 156.8725 r[j][t][15,6] + 828.59 r[j][t][16,6] + 9.5 r[j][t][17,6]
# 1300.0
# 187.76 r[j][t][0,6] + 686.3 r[j][t][1,6] + 265.28 r[j][t][2,6] + 135.01 r[j][t][3,6] + 92.4 r[j][t][4,6] + 212.0 r[j][t][5,6] + 223.25 r[j][t][6,6] + 343.21000000000004 r[j][t][7,6] + 162.9 r[j][t][8,6] + 345.79 r[j][t][9,6] + 273.22 r[j][t][10,6] + 267.34000000000003 r[j][t][11,6] + 162.16 r[j][t][12,6] + 578.1899999999999 r[j][t][13,6] + 131.55 r[j][t][14,6] + 165.35 r[j][t][15,6] + 241.10999999999999 r[j][t][16,6] + 51.300000000000004 r[j][t][17,6]
# 410.0
# 26.461 r[j][t][0,6] + 26.115 r[j][t][1,6] + 3.464 r[j][t][2,6] + 4.843 r[j][t][3,6] + 3.384 r[j][t][4,6] + 12.135 r[j][t][5,6] + 9.203 r[j][t][6,6] + 11.523 r[j][t][7,6] + 11.911 r[j][t][8,6] + 12.706 r[j][t][9,6] + 8.548 r[j][t][10,6] + 8.822 r[j][t][11,6] + 1.751 r[j][t][12,6] + 13.668000000000001 r[j][t][13,6] + 11.23 r[j][t][14,6] + 5.5325 r[j][t][15,6] + 9.56 r[j][t][16,6] + 0.28500000000000003 r[j][t][17,6]
# 11.0
# 17.756 r[j][t][0,6] + 31.1 r[j][t][1,6] + 7.25 r[j][t][2,6] + 0.745 r[j][t][3,6] + 4.7765 r[j][t][4,6] + 11.3575 r[j][t][5,6] + 13.403 r[j][t][6,6] + 14.23 r[j][t][7,6] + 10.401 r[j][t][8,6] + 14.741 r[j][t][9,6] + 16.086000000000002 r[j][t][10,6] + 10.664 r[j][t][11,6] + 6.922 r[j][t][12,6] + 16.666 r[j][t][13,6] + 9.04 r[j][t][14,6] + 7.3725000000000005 r[j][t][15,6] + 10.789000000000001 r[j][t][16,6] + 0.494 r[j][t][17,6]
# 11.0
# 21.05 r[j][t][0,6] + 536.6 r[j][t][1,6] + 190.76 r[j][t][2,6] + 812.6 r[j][t][3,6] + 254.39999999999998 r[j][t][4,6] + 804.095 r[j][t][5,6] + 680.0799999999999 r[j][t][6,6] + 363.19 r[j][t][7,6] + 449.01 r[j][t][8,6] + 1187.34 r[j][t][9,6] + 603.49 r[j][t][10,6] + 343.92 r[j][t][11,6] + 955.05 r[j][t][12,6] + 983.5 r[j][t][13,6] + 1151.52 r[j][t][14,6] + 248.91 r[j][t][15,6] + 2177.22 r[j][t][16,6] + 5.7 r[j][t][17,6]
# 900.0
# 134.7075 r[j][t][0,6] + 1.8665000000000003 r[j][t][1,6] + 0.4224 r[j][t][2,6] + 0.24180000000000001 r[j][t][3,6] + 0.3436 r[j][t][4,6] + 0.5129 r[j][t][5,6] + 0.9322 r[j][t][6,6] + 0.9980000000000001 r[j][t][7,6] + 0.5441 r[j][t][8,6] + 1.1137000000000001 r[j][t][9,6] + 1.2186000000000001 r[j][t][10,6] + 0.6628000000000001 r[j][t][11,6] + 0.5465 r[j][t][12,6] + 1.0993000000000002 r[j][t][13,6] + 0.6021000000000001 r[j][t][14,6] + 0.4953 r[j][t][15,6] + 161.63510000000002 r[j][t][16,6] + 0.0589 r[j][t][17,6]
# 1.2
# ...
# -0.0
# -1.0 u[i][tau][t][33,0,3] + -1.0 u[i][tau][t][33,1,3] + -1.0 u[i][tau][t][33,2,3] + -1.0 u[i][tau][t][33,3,3] + 227.0 r[j][t][9,3] + 340.0 r[j][t][10,3]
# -0.0
# -1.0 u[i][tau][t][33,0,4] + -1.0 u[i][tau][t][33,1,4] + -1.0 u[i][tau][t][33,2,4] + -1.0 u[i][tau][t][33,3,4] + -1.0 u[i][tau][t][33,4,4] + 227.0 r[j][t][9,4] + 340.0 r[j][t][10,4]
# -0.0
# -1.0 u[i][tau][t][33,0,5] + -1.0 u[i][tau][t][33,1,5] + -1.0 u[i][tau][t][33,2,5] + -1.0 u[i][tau][t][33,3,5] + -1.0 u[i][tau][t][33,4,5] + -1.0 u[i][tau][t][33,5,5] + 227.0 r[j][t][9,5] + 340.0 r[j][t][10,5]
# -0.0
# -1.0 u[i][tau][t][33,0,6] + -1.0 u[i][tau][t][33,1,6] + -1.0 u[i][tau][t][33,2,6] + -1.0 u[i][tau][t][33,3,6] + -1.0 u[i][tau][t][33,4,6] + -1.0 u[i][tau][t][33,5,6] + -1.0 u[i][tau][t][33,6,6] + 227.0 r[j][t][9,6] + 340.0 r[j][t][10,6]
# -0.0
# -1.0 u[i][tau][t][34,0,0] + 30.0 r[j][t][9,0]
# -0.0
# -1.0 u[i][tau][t][34,0,1] + -1.0 u[i][tau][t][34,1,1] + 30.0 r[j][t][9,1]
# -0.0
# -1.0 u[i][tau][t][34,0,2] + -1.0 u[i][tau][t][34,1,2] + -1.0 u[i][tau][t][34,2,2] + 30.0 r[j][t][9,2]
# -0.0
# -1.0 u[i][tau][t][34,0,3] + -1.0 u[i][tau][t][34,1,3] + -1.0 u[i][tau][t][34,2,3] + -1.0 u[i][tau][t][34,3,3] + 30.0 r[j][t][9,3]
# -0.0
# -1.0 u[i][tau][t][34,0,4] + -1.0 u[i][tau][t][34,1,4] + -1.0 u[i][tau][t][34,2,4] + -1.0 u[i][tau][t][34,3,4] + -1.0 u[i][tau][t][34,4,4] + 30.0 r[j][t][9,4]
# -0.0
# -1.0 u[i][tau][t][34,0,5] + -1.0 u[i][tau][t][34,1,5] + -1.0 u[i][tau][t][34,2,5] + -1.0 u[i][tau][t][34,3,5] + -1.0 u[i][tau][t][34,4,5] + -1.0 u[i][tau][t][34,5,5] + 30.0 r[j][t][9,5]
# -0.0
# -1.0 u[i][tau][t][34,0,6] + -1.0 u[i][tau][t][34,1,6] + -1.0 u[i][tau][t][34,2,6] + -1.0 u[i][tau][t][34,3,6] + -1.0 u[i][tau][t][34,4,6] + -1.0 u[i][tau][t][34,5,6] + -1.0 u[i][tau][t][34,6,6] + 30.0 r[j][t][9,6]
# -0.0
# -1.0 u[i][tau][t][35,0,0] + 227.0 r[j][t][10,0]
# -0.0
# -1.0 u[i][tau][t][35,0,1] + -1.0 u[i][tau][t][35,1,1] + 227.0 r[j][t][10,1]
# -0.0
# -1.0 u[i][tau][t][35,0,2] + -1.0 u[i][tau][t][35,1,2] + -1.0 u[i][tau][t][35,2,2] + 227.0 r[j][t][10,2]
# -0.0
# -1.0 u[i][tau][t][35,0,3] + -1.0 u[i][tau][t][35,1,3] + -1.0 u[i][tau][t][35,2,3] + -1.0 u[i][tau][t][35,3,3] + 227.0 r[j][t][10,3]
# -0.0
# -1.0 u[i][tau][t][35,0,4] + -1.0 u[i][tau][t][35,1,4] + -1.0 u[i][tau][t][35,2,4] + -1.0 u[i][tau][t][35,3,4] + -1.0 u[i][tau][t][35,4,4] + 227.0 r[j][t][10,4]
# -0.0
# -1.0 u[i][tau][t][35,0,5] + -1.0 u[i][tau][t][35,1,5] + -1.0 u[i][tau][t][35,2,5] + -1.0 u[i][tau][t][35,3,5] + -1.0 u[i][tau][t][35,4,5] + -1.0 u[i][tau][t][35,5,5] + 227.0 r[j][t][10,5]
# -0.0
# -1.0 u[i][tau][t][35,0,6] + -1.0 u[i][tau][t][35,1,6] + -1.0 u[i][tau][t][35,2,6] + -1.0 u[i][tau][t][35,3,6] + -1.0 u[i][tau][t][35,4,6] + -1.0 u[i][tau][t][35,5,6] + -1.0 u[i][tau][t][35,6,6] + 227.0 r[j][t][10,6]
# -0.0
# -1.0 u[i][tau][t][36,0,0] + 113.0 r[j][t][10,0] + 480.0 r[j][t][12,0]
# -0.0
# -1.0 u[i][tau][t][36,0,1] + -1.0 u[i][tau][t][36,1,1] + 113.0 r[j][t][10,1] + 480.0 r[j][t][12,1]
# -0.0
# -1.0 u[i][tau][t][36,0,2] + -1.0 u[i][tau][t][36,1,2] + -1.0 u[i][tau][t][36,2,2] + 113.0 r[j][t][10,2] + 480.0 r[j][t][12,2]
# -0.0
# -1.0 u[i][tau][t][36,0,3] + -1.0 u[i][tau][t][36,1,3] + -1.0 u[i][tau][t][36,2,3] + -1.0 u[i][tau][t][36,3,3] + 113.0 r[j][t][10,3] + 480.0 r[j][t][12,3]
# -0.0
# -1.0 u[i][tau][t][36,0,4] + -1.0 u[i][tau][t][36,1,4] + -1.0 u[i][tau][t][36,2,4] + -1.0 u[i][tau][t][36,3,4] + -1.0 u[i][tau][t][36,4,4] + 113.0 r[j][t][10,4] + 480.0 r[j][t][12,4]
# -0.0
# -1.0 u[i][tau][t][36,0,5] + -1.0 u[i][tau][t][36,1,5] + -1.0 u[i][tau][t][36,2,5] + -1.0 u[i][tau][t][36,3,5] + -1.0 u[i][tau][t][36,4,5] + -1.0 u[i][tau][t][36,5,5] + 113.0 r[j][t][10,5] + 480.0 r[j][t][12,5]
# -0.0
# -1.0 u[i][tau][t][36,0,6] + -1.0 u[i][tau][t][36,1,6] + -1.0 u[i][tau][t][36,2,6] + -1.0 u[i][tau][t][36,3,6] + -1.0 u[i][tau][t][36,4,6] + -1.0 u[i][tau][t][36,5,6] + -1.0 u[i][tau][t][36,6,6] + 113.0 r[j][t][10,6] + 480.0 r[j][t][12,6]
# -0.0
# -1.0 u[i][tau][t][37,0,0] + 113.0 r[j][t][10,0] + 397.0 r[j][t][16,0]
# -0.0
# -1.0 u[i][tau][t][37,0,1] + -1.0 u[i][tau][t][37,1,1] + 113.0 r[j][t][10,1] + 397.0 r[j][t][16,1]
# -0.0
# -1.0 u[i][tau][t][37,0,2] + -1.0 u[i][tau][t][37,1,2] + -1.0 u[i][tau][t][37,2,2] + 113.0 r[j][t][10,2] + 397.0 r[j][t][16,2]
# -0.0
# -1.0 u[i][tau][t][37,0,3] + -1.0 u[i][tau][t][37,1,3] + -1.0 u[i][tau][t][37,2,3] + -1.0 u[i][tau][t][37,3,3] + 113.0 r[j][t][10,3] + 397.0 r[j][t][16,3]
# -0.0
# -1.0 u[i][tau][t][37,0,4] + -1.0 u[i][tau][t][37,1,4] + -1.0 u[i][tau][t][37,2,4] + -1.0 u[i][tau][t][37,3,4] + -1.0 u[i][tau][t][37,4,4] + 113.0 r[j][t][10,4] + 397.0 r[j][t][16,4]
# -0.0
# -1.0 u[i][tau][t][37,0,5] + -1.0 u[i][tau][t][37,1,5] + -1.0 u[i][tau][t][37,2,5] + -1.0 u[i][tau][t][37,3,5] + -1.0 u[i][tau][t][37,4,5] + -1.0 u[i][tau][t][37,5,5] + 113.0 r[j][t][10,5] + 397.0 r[j][t][16,5]
# -0.0
# -1.0 u[i][tau][t][37,0,6] + -1.0 u[i][tau][t][37,1,6] + -1.0 u[i][tau][t][37,2,6] + -1.0 u[i][tau][t][37,3,6] + -1.0 u[i][tau][t][37,4,6] + -1.0 u[i][tau][t][37,5,6] + -1.0 u[i][tau][t][37,6,6] + 113.0 r[j][t][10,6] + 397.0 r[j][t][16,6]
# -0.0
# -1.0 u[i][tau][t][38,0,0] + 15.0 r[j][t][10,0]
# -0.0
# -1.0 u[i][tau][t][38,0,1] + -1.0 u[i][tau][t][38,1,1] + 15.0 r[j][t][10,1]
# -0.0
# -1.0 u[i][tau][t][38,0,2] + -1.0 u[i][tau][t][38,1,2] + -1.0 u[i][tau][t][38,2,2] + 15.0 r[j][t][10,2]
# -0.0
# -1.0 u[i][tau][t][38,0,3] + -1.0 u[i][tau][t][38,1,3] + -1.0 u[i][tau][t][38,2,3] + -1.0 u[i][tau][t][38,3,3] + 15.0 r[j][t][10,3]
# -0.0
# -1.0 u[i][tau][t][38,0,4] + -1.0 u[i][tau][t][38,1,4] + -1.0 u[i][tau][t][38,2,4] + -1.0 u[i][tau][t][38,3,4] + -1.0 u[i][tau][t][38,4,4] + 15.0 r[j][t][10,4]
# -0.0
# -1.0 u[i][tau][t][38,0,5] + -1.0 u[i][tau][t][38,1,5] + -1.0 u[i][tau][t][38,2,5] + -1.0 u[i][tau][t][38,3,5] + -1.0 u[i][tau][t][38,4,5] + -1.0 u[i][tau][t][38,5,5] + 15.0 r[j][t][10,5]
# -0.0
# -1.0 u[i][tau][t][38,0,6] + -1.0 u[i][tau][t][38,1,6] + -1.0 u[i][tau][t][38,2,6] + -1.0 u[i][tau][t][38,3,6] + -1.0 u[i][tau][t][38,4,6] + -1.0 u[i][tau][t][38,5,6] + -1.0 u[i][tau][t][38,6,6] + 15.0 r[j][t][10,6]
# -0.0
# -1.0 u[i][tau][t][39,0,0] + 50.0 r[j][t][10,0] + 100.0 r[j][t][13,0]
# -0.0
# -1.0 u[i][tau][t][39,0,1] + -1.0 u[i][tau][t][39,1,1] + 50.0 r[j][t][10,1] + 100.0 r[j][t][13,1]
# -0.0
# -1.0 u[i][tau][t][39,0,2] + -1.0 u[i][tau][t][39,1,2] + -1.0 u[i][tau][t][39,2,2] + 50.0 r[j][t][10,2] + 100.0 r[j][t][13,2]
# -0.0
# -1.0 u[i][tau][t][39,0,3] + -1.0 u[i][tau][t][39,1,3] + -1.0 u[i][tau][t][39,2,3] + -1.0 u[i][tau][t][39,3,3] + 50.0 r[j][t][10,3] + 100.0 r[j][t][13,3]
# -0.0
# -1.0 u[i][tau][t][39,0,4] + -1.0 u[i][tau][t][39,1,4] + -1.0 u[i][tau][t][39,2,4] + -1.0 u[i][tau][t][39,3,4] + -1.0 u[i][tau][t][39,4,4] + 50.0 r[j][t][10,4] + 100.0 r[j][t][13,4]
# -0.0
# -1.0 u[i][tau][t][39,0,5] + -1.0 u[i][tau][t][39,1,5] + -1.0 u[i][tau][t][39,2,5] + -1.0 u[i][tau][t][39,3,5] + -1.0 u[i][tau][t][39,4,5] + -1.0 u[i][tau][t][39,5,5] + 50.0 r[j][t][10,5] + 100.0 r[j][t][13,5]
# -0.0
# -1.0 u[i][tau][t][39,0,6] + -1.0 u[i][tau][t][39,1,6] + -1.0 u[i][tau][t][39,2,6] + -1.0 u[i][tau][t][39,3,6] + -1.0 u[i][tau][t][39,4,6] + -1.0 u[i][tau][t][39,5,6] + -1.0 u[i][tau][t][39,6,6] + 50.0 r[j][t][10,6] + 100.0 r[j][t][13,6]
# -0.0
# -1.0 u[i][tau][t][40,0,0] + 150.0 r[j][t][11,0]
# -0.0
# -1.0 u[i][tau][t][40,0,1] + -1.0 u[i][tau][t][40,1,1] + 150.0 r[j][t][11,1]
# -0.0
# -1.0 u[i][tau][t][40,0,2] + -1.0 u[i][tau][t][40,1,2] + -1.0 u[i][tau][t][40,2,2] + 150.0 r[j][t][11,2]
# -0.0
# -1.0 u[i][tau][t][40,0,3] + -1.0 u[i][tau][t][40,1,3] + -1.0 u[i][tau][t][40,2,3] + -1.0 u[i][tau][t][40,3,3] + 150.0 r[j][t][11,3]
# -0.0
# -1.0 u[i][tau][t][40,0,4] + -1.0 u[i][tau][t][40,1,4] + -1.0 u[i][tau][t][40,2,4] + -1.0 u[i][tau][t][40,3,4] + -1.0 u[i][tau][t][40,4,4] + 150.0 r[j][t][11,4]
# -0.0
# -1.0 u[i][tau][t][40,0,5] + -1.0 u[i][tau][t][40,1,5] + -1.0 u[i][tau][t][40,2,5] + -1.0 u[i][tau][t][40,3,5] + -1.0 u[i][tau][t][40,4,5] + -1.0 u[i][tau][t][40,5,5] + 150.0 r[j][t][11,5]
# -0.0
# -1.0 u[i][tau][t][40,0,6] + -1.0 u[i][tau][t][40,1,6] + -1.0 u[i][tau][t][40,2,6] + -1.0 u[i][tau][t][40,3,6] + -1.0 u[i][tau][t][40,4,6] + -1.0 u[i][tau][t][40,5,6] + -1.0 u[i][tau][t][40,6,6] + 150.0 r[j][t][11,6]
# -0.0
# -1.0 u[i][tau][t][41,0,0] + 120.0 r[j][t][12,0] + 30.0 r[j][t][13,0]
# -0.0
# -1.0 u[i][tau][t][41,0,1] + -1.0 u[i][tau][t][41,1,1] + 120.0 r[j][t][12,1] + 30.0 r[j][t][13,1]
# -0.0
# -1.0 u[i][tau][t][41,0,2] + -1.0 u[i][tau][t][41,1,2] + -1.0 u[i][tau][t][41,2,2] + 120.0 r[j][t][12,2] + 30.0 r[j][t][13,2]
# -0.0
# -1.0 u[i][tau][t][41,0,3] + -1.0 u[i][tau][t][41,1,3] + -1.0 u[i][tau][t][41,2,3] + -1.0 u[i][tau][t][41,3,3] + 120.0 r[j][t][12,3] + 30.0 r[j][t][13,3]
# -0.0
# -1.0 u[i][tau][t][41,0,4] + -1.0 u[i][tau][t][41,1,4] + -1.0 u[i][tau][t][41,2,4] + -1.0 u[i][tau][t][41,3,4] + -1.0 u[i][tau][t][41,4,4] + 120.0 r[j][t][12,4] + 30.0 r[j][t][13,4]
# -0.0
# -1.0 u[i][tau][t][41,0,5] + -1.0 u[i][tau][t][41,1,5] + -1.0 u[i][tau][t][41,2,5] + -1.0 u[i][tau][t][41,3,5] + -1.0 u[i][tau][t][41,4,5] + -1.0 u[i][tau][t][41,5,5] + 120.0 r[j][t][12,5] + 30.0 r[j][t][13,5]
# -0.0
# -1.0 u[i][tau][t][41,0,6] + -1.0 u[i][tau][t][41,1,6] + -1.0 u[i][tau][t][41,2,6] + -1.0 u[i][tau][t][41,3,6] + -1.0 u[i][tau][t][41,4,6] + -1.0 u[i][tau][t][41,5,6] + -1.0 u[i][tau][t][41,6,6] + 120.0 r[j][t][12,6] + 30.0 r[j][t][13,6]
# -0.0
# -1.0 u[i][tau][t][42,0,0] + 60.0 r[j][t][12,0] + 130.0 r[j][t][14,0]
# -0.0
# -1.0 u[i][tau][t][42,0,1] + -1.0 u[i][tau][t][42,1,1] + 60.0 r[j][t][12,1] + 130.0 r[j][t][14,1]
# -0.0
# -1.0 u[i][tau][t][42,0,2] + -1.0 u[i][tau][t][42,1,2] + -1.0 u[i][tau][t][42,2,2] + 60.0 r[j][t][12,2] + 130.0 r[j][t][14,2]
# -0.0
# -1.0 u[i][tau][t][42,0,3] + -1.0 u[i][tau][t][42,1,3] + -1.0 u[i][tau][t][42,2,3] + -1.0 u[i][tau][t][42,3,3] + 60.0 r[j][t][12,3] + 130.0 r[j][t][14,3]
# -0.0
# -1.0 u[i][tau][t][42,0,4] + -1.0 u[i][tau][t][42,1,4] + -1.0 u[i][tau][t][42,2,4] + -1.0 u[i][tau][t][42,3,4] + -1.0 u[i][tau][t][42,4,4] + 60.0 r[j][t][12,4] + 130.0 r[j][t][14,4]
# -0.0
# -1.0 u[i][tau][t][42,0,5] + -1.0 u[i][tau][t][42,1,5] + -1.0 u[i][tau][t][42,2,5] + -1.0 u[i][tau][t][42,3,5] + -1.0 u[i][tau][t][42,4,5] + -1.0 u[i][tau][t][42,5,5] + 60.0 r[j][t][12,5] + 130.0 r[j][t][14,5]
# -0.0
# -1.0 u[i][tau][t][42,0,6] + -1.0 u[i][tau][t][42,1,6] + -1.0 u[i][tau][t][42,2,6] + -1.0 u[i][tau][t][42,3,6] + -1.0 u[i][tau][t][42,4,6] + -1.0 u[i][tau][t][42,5,6] + -1.0 u[i][tau][t][42,6,6] + 60.0 r[j][t][12,6] + 130.0 r[j][t][14,6]
# -0.0
# -1.0 u[i][tau][t][43,0,0] + 150.0 r[j][t][13,0]
# -0.0
# -1.0 u[i][tau][t][43,0,1] + -1.0 u[i][tau][t][43,1,1] + 150.0 r[j][t][13,1]
# -0.0
# -1.0 u[i][tau][t][43,0,2] + -1.0 u[i][tau][t][43,1,2] + -1.0 u[i][tau][t][43,2,2] + 150.0 r[j][t][13,2]
# -0.0
# -1.0 u[i][tau][t][43,0,3] + -1.0 u[i][tau][t][43,1,3] + -1.0 u[i][tau][t][43,2,3] + -1.0 u[i][tau][t][43,3,3] + 150.0 r[j][t][13,3]
# -0.0
# -1.0 u[i][tau][t][43,0,4] + -1.0 u[i][tau][t][43,1,4] + -1.0 u[i][tau][t][43,2,4] + -1.0 u[i][tau][t][43,3,4] + -1.0 u[i][tau][t][43,4,4] + 150.0 r[j][t][13,4]
# -0.0
# -1.0 u[i][tau][t][43,0,5] + -1.0 u[i][tau][t][43,1,5] + -1.0 u[i][tau][t][43,2,5] + -1.0 u[i][tau][t][43,3,5] + -1.0 u[i][tau][t][43,4,5] + -1.0 u[i][tau][t][43,5,5] + 150.0 r[j][t][13,5]
# -0.0
# -1.0 u[i][tau][t][43,0,6] + -1.0 u[i][tau][t][43,1,6] + -1.0 u[i][tau][t][43,2,6] + -1.0 u[i][tau][t][43,3,6] + -1.0 u[i][tau][t][43,4,6] + -1.0 u[i][tau][t][43,5,6] + -1.0 u[i][tau][t][43,6,6] + 150.0 r[j][t][13,6]
# -0.0
# -1.0 u[i][tau][t][44,0,0] + 28.0 r[j][t][13,0]
# -0.0
# -1.0 u[i][tau][t][44,0,1] + -1.0 u[i][tau][t][44,1,1] + 28.0 r[j][t][13,1]
# -0.0
# -1.0 u[i][tau][t][44,0,2] + -1.0 u[i][tau][t][44,1,2] + -1.0 u[i][tau][t][44,2,2] + 28.0 r[j][t][13,2]
# -0.0
# -1.0 u[i][tau][t][44,0,3] + -1.0 u[i][tau][t][44,1,3] + -1.0 u[i][tau][t][44,2,3] + -1.0 u[i][tau][t][44,3,3] + 28.0 r[j][t][13,3]
# -0.0
# -1.0 u[i][tau][t][44,0,4] + -1.0 u[i][tau][t][44,1,4] + -1.0 u[i][tau][t][44,2,4] + -1.0 u[i][tau][t][44,3,4] + -1.0 u[i][tau][t][44,4,4] + 28.0 r[j][t][13,4]
# -0.0
# -1.0 u[i][tau][t][44,0,5] + -1.0 u[i][tau][t][44,1,5] + -1.0 u[i][tau][t][44,2,5] + -1.0 u[i][tau][t][44,3,5] + -1.0 u[i][tau][t][44,4,5] + -1.0 u[i][tau][t][44,5,5] + 28.0 r[j][t][13,5]
# -0.0
# -1.0 u[i][tau][t][44,0,6] + -1.0 u[i][tau][t][44,1,6] + -1.0 u[i][tau][t][44,2,6] + -1.0 u[i][tau][t][44,3,6] + -1.0 u[i][tau][t][44,4,6] + -1.0 u[i][tau][t][44,5,6] + -1.0 u[i][tau][t][44,6,6] + 28.0 r[j][t][13,6]
# -0.0
# -1.0 u[i][tau][t][45,0,0] + 113.0 r[j][t][13,0]
# -0.0
# -1.0 u[i][tau][t][45,0,1] + -1.0 u[i][tau][t][45,1,1] + 113.0 r[j][t][13,1]
# -0.0
# -1.0 u[i][tau][t][45,0,2] + -1.0 u[i][tau][t][45,1,2] + -1.0 u[i][tau][t][45,2,2] + 113.0 r[j][t][13,2]
# -0.0
# -1.0 u[i][tau][t][45,0,3] + -1.0 u[i][tau][t][45,1,3] + -1.0 u[i][tau][t][45,2,3] + -1.0 u[i][tau][t][45,3,3] + 113.0 r[j][t][13,3]
# -0.0
# -1.0 u[i][tau][t][45,0,4] + -1.0 u[i][tau][t][45,1,4] + -1.0 u[i][tau][t][45,2,4] + -1.0 u[i][tau][t][45,3,4] + -1.0 u[i][tau][t][45,4,4] + 113.0 r[j][t][13,4]
# -0.0
# -1.0 u[i][tau][t][45,0,5] + -1.0 u[i][tau][t][45,1,5] + -1.0 u[i][tau][t][45,2,5] + -1.0 u[i][tau][t][45,3,5] + -1.0 u[i][tau][t][45,4,5] + -1.0 u[i][tau][t][45,5,5] + 113.0 r[j][t][13,5]
# -0.0
# -1.0 u[i][tau][t][45,0,6] + -1.0 u[i][tau][t][45,1,6] + -1.0 u[i][tau][t][45,2,6] + -1.0 u[i][tau][t][45,3,6] + -1.0 u[i][tau][t][45,4,6] + -1.0 u[i][tau][t][45,5,6] + -1.0 u[i][tau][t][45,6,6] + 113.0 r[j][t][13,6]
# -0.0
# -1.0 u[i][tau][t][46,0,0] + 90.0 r[j][t][14,0]
# -0.0
# -1.0 u[i][tau][t][46,0,1] + -1.0 u[i][tau][t][46,1,1] + 90.0 r[j][t][14,1]
# -0.0
# -1.0 u[i][tau][t][46,0,2] + -1.0 u[i][tau][t][46,1,2] + -1.0 u[i][tau][t][46,2,2] + 90.0 r[j][t][14,2]
# -0.0
# -1.0 u[i][tau][t][46,0,3] + -1.0 u[i][tau][t][46,1,3] + -1.0 u[i][tau][t][46,2,3] + -1.0 u[i][tau][t][46,3,3] + 90.0 r[j][t][14,3]
# -0.0
# -1.0 u[i][tau][t][46,0,4] + -1.0 u[i][tau][t][46,1,4] + -1.0 u[i][tau][t][46,2,4] + -1.0 u[i][tau][t][46,3,4] + -1.0 u[i][tau][t][46,4,4] + 90.0 r[j][t][14,4]
# -0.0
# -1.0 u[i][tau][t][46,0,5] + -1.0 u[i][tau][t][46,1,5] + -1.0 u[i][tau][t][46,2,5] + -1.0 u[i][tau][t][46,3,5] + -1.0 u[i][tau][t][46,4,5] + -1.0 u[i][tau][t][46,5,5] + 90.0 r[j][t][14,5]
# -0.0
# -1.0 u[i][tau][t][46,0,6] + -1.0 u[i][tau][t][46,1,6] + -1.0 u[i][tau][t][46,2,6] + -1.0 u[i][tau][t][46,3,6] + -1.0 u[i][tau][t][46,4,6] + -1.0 u[i][tau][t][46,5,6] + -1.0 u[i][tau][t][46,6,6] + 90.0 r[j][t][14,6]
# -0.0
# -1.0 u[i][tau][t][47,0,0] + 62.5 r[j][t][15,0]
# -0.0
# -1.0 u[i][tau][t][47,0,1] + -1.0 u[i][tau][t][47,1,1] + 62.5 r[j][t][15,1]
# -0.0
# -1.0 u[i][tau][t][47,0,2] + -1.0 u[i][tau][t][47,1,2] + -1.0 u[i][tau][t][47,2,2] + 62.5 r[j][t][15,2]
# -0.0
# -1.0 u[i][tau][t][47,0,3] + -1.0 u[i][tau][t][47,1,3] + -1.0 u[i][tau][t][47,2,3] + -1.0 u[i][tau][t][47,3,3] + 62.5 r[j][t][15,3]
# -0.0
# -1.0 u[i][tau][t][47,0,4] + -1.0 u[i][tau][t][47,1,4] + -1.0 u[i][tau][t][47,2,4] + -1.0 u[i][tau][t][47,3,4] + -1.0 u[i][tau][t][47,4,4] + 62.5 r[j][t][15,4]
# -0.0
# -1.0 u[i][tau][t][47,0,5] + -1.0 u[i][tau][t][47,1,5] + -1.0 u[i][tau][t][47,2,5] + -1.0 u[i][tau][t][47,3,5] + -1.0 u[i][tau][t][47,4,5] + -1.0 u[i][tau][t][47,5,5] + 62.5 r[j][t][15,5]
# -0.0
# -1.0 u[i][tau][t][47,0,6] + -1.0 u[i][tau][t][47,1,6] + -1.0 u[i][tau][t][47,2,6] + -1.0 u[i][tau][t][47,3,6] + -1.0 u[i][tau][t][47,4,6] + -1.0 u[i][tau][t][47,5,6] + -1.0 u[i][tau][t][47,6,6] + 62.5 r[j][t][15,6]
# -0.0
# -1.0 u[i][tau][t][48,0,0] + 190.0 r[j][t][17,0]
# -0.0
# -1.0 u[i][tau][t][48,0,1] + -1.0 u[i][tau][t][48,1,1] + 190.0 r[j][t][17,1]
# -0.0
# -1.0 u[i][tau][t][48,0,2] + -1.0 u[i][tau][t][48,1,2] + -1.0 u[i][tau][t][48,2,2] + 190.0 r[j][t][17,2]
# -0.0
# -1.0 u[i][tau][t][48,0,3] + -1.0 u[i][tau][t][48,1,3] + -1.0 u[i][tau][t][48,2,3] + -1.0 u[i][tau][t][48,3,3] + 190.0 r[j][t][17,3]
# -0.0
# -1.0 u[i][tau][t][48,0,4] + -1.0 u[i][tau][t][48,1,4] + -1.0 u[i][tau][t][48,2,4] + -1.0 u[i][tau][t][48,3,4] + -1.0 u[i][tau][t][48,4,4] + 190.0 r[j][t][17,4]
# -0.0
# -1.0 u[i][tau][t][48,0,5] + -1.0 u[i][tau][t][48,1,5] + -1.0 u[i][tau][t][48,2,5] + -1.0 u[i][tau][t][48,3,5] + -1.0 u[i][tau][t][48,4,5] + -1.0 u[i][tau][t][48,5,5] + 190.0 r[j][t][17,5]
# -0.0
# -1.0 u[i][tau][t][48,0,6] + -1.0 u[i][tau][t][48,1,6] + -1.0 u[i][tau][t][48,2,6] + -1.0 u[i][tau][t][48,3,6] + -1.0 u[i][tau][t][48,4,6] + -1.0 u[i][tau][t][48,5,6] + -1.0 u[i][tau][t][48,6,6] + 190.0 r[j][t][17,6]
# -0.0

# %%
model.computeIIS()
model.write('iismodel.ilp')
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# IIS computation: initial model status unknown, solving to determine model status
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# IIS runtime: 0.02 seconds (0.00 work units)
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 model.computeIIS()
#       2 model.write('iismodel.ilp')
#
# File src/gurobipy/_model.pyx:1206, in gurobipy._model.Model.computeIIS()
#
# GurobiError: Cannot compute IIS on a feasible model

# %%
for tau in range(6):
    print(model.getVarByName(f"u[i][tau][t][48,{tau},6]"))
# Out:
# <gurobi.Var u[i][tau][t][48,0,6]>
# <gurobi.Var u[i][tau][t][48,1,6]>
# <gurobi.Var u[i][tau][t][48,2,6]>
# <gurobi.Var u[i][tau][t][48,3,6]>
# <gurobi.Var u[i][tau][t][48,4,6]>
# <gurobi.Var u[i][tau][t][48,5,6]>
